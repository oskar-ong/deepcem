# %%
from results_analysis import generate_comparison_latex, plot_degradation_barplot, plot_degradation_boxplot, query_metrics, query_metrics_individual

# %% [markdown]
# # JOB ID: 9790092
#
# Dataset: music
#
# Trainset size: Full
#
# Pollutions: source, low, medium, high
#
# lm: roberta

# %% [markdown]
# # 9798848

# %% [markdown]
# Dataset: music
#
# Trainset size: Full
#
# Pollutions: source, low, medium, high
#
# lm: roberta
#
# learning rate: 2e-5

# %%
from results_analysis import investigate_outliers, query_metrics_p1
jobid = 9798848
df = query_metrics(jobid)

latex_code = generate_comparison_latex(df, test_metric='test')

# Define your threshold
threshold = 0.05

df = query_metrics_p1(jobid)

# Filter the aggregated dataframe to find problematic configurations
high_sd_df = df[df['std_f1'] > threshold].copy()

print(f"Found {len(high_sd_df)} rows with Standard Deviation > {threshold}")
display(high_sd_df)

print(latex_code)




outlier_details = investigate_outliers(high_sd_df.iloc[2], jobid)
display(outlier_details)

df = query_metrics_individual(jobid)

display(df)
plot_degradation_boxplot(df, "music", "main", "roberta")
# Out:
# Found 8 rows with Standard Deviation > 0.05
#    dataset         entity metric_type  mean_f1    std_f1  num_seeds  \
# 0    music           area      phase1   0.4692  0.179934          5
# 1    music           area      phase1   0.7944  0.220876          5
# 2    music           area      phase1   0.8110  0.108711          4
# 3    music           area      phase1   0.9246  0.089408          5
# 12   music          label      phase1   0.5872  0.215521          5
# 16   music         medium      phase1   0.6848  0.159514          5
# 25   music      recording      phase1   0.8660  0.260569          5
# 32   music  release_group      phase1   0.6342  0.215346          5
#
#     train_size pollution  epochs
# 0          1.0      high      10
# 1          1.0       low      10
# 2          1.0    medium      10
# 3          1.0    source      10
# 12         1.0      high      10
# 16         1.0      high      10
# 25         1.0       low      10
# 32         1.0      high      10
# \begin{table}[h]
# \centering
# \caption{Main Experiment: Baseline vs. RETEM - Dataset music}
# \label{tab:main_exp_}}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{RETEM}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# area & source & & \textbf{0.9802} & 0.0219 & & 0.9618 & 0.0325 \\
# area & low & & \textbf{0.9160} & 0.0274 & & 0.9024 & 0.0836 \\
# area & medium & & 0.6660 & 0.1706 & & \textbf{0.8758} & 0.0336 \\
# area & high & & 0.4986 & 0.1847 & & \textbf{0.6238} & 0.2146 \\
# artist & source & & \textbf{0.9952} & 0.0027 & & 0.9200 & 0.0663 \\
# artist & low & & \textbf{0.9972} & 0.0011 & & 0.8614 & 0.1440 \\
# artist & medium & & \textbf{0.9956} & 0.0009 & & 0.9665 & 0.0272 \\
# artist & high & & \textbf{0.9956} & 0.0026 & & 0.8358 & 0.2082 \\
# artist_credit & source & & 0.9970 & nan & & \textbf{0.9972} & 0.0018 \\
# artist_credit & low & & 0.9900 & 0.0027 & & \textbf{0.9916} & 0.0065 \\
# artist_credit & medium & & 0.9896 & 0.0026 & & \textbf{0.9898} & 0.0034 \\
# artist_credit & high & & \textbf{0.9422} & 0.0094 & & 0.8734 & 0.1818 \\
# label & source & & \textbf{0.9754} & 0.0054 & & 0.9670 & 0.0056 \\
# label & low & & \textbf{0.9540} & 0.0000 & & 0.9368 & 0.0134 \\
# label & medium & & 0.8864 & 0.0071 & & \textbf{0.8898} & 0.0257 \\
# label & high & & 0.7452 & 0.1936 & & \textbf{0.7872} & 0.0793 \\
# medium & source & & 0.8220 & 0.0850 & & \textbf{1.0000} & 0.0000 \\
# medium & low & & 0.9110 & 0.0055 & & \textbf{0.9786} & 0.0083 \\
# medium & medium & & 0.8568 & 0.0102 & & \textbf{0.9898} & 0.0078 \\
# medium & high & & 0.7658 & 0.0294 & & \textbf{0.9624} & 0.0202 \\
# place & source & & \textbf{0.9760} & 0.0022 & & 0.9696 & 0.0065 \\
# place & low & & \textbf{0.9656} & 0.0060 & & 0.9598 & 0.0191 \\
# place & medium & & \textbf{0.9414} & 0.0048 & & 0.9347 & 0.0087 \\
# place & high & & \textbf{0.8692} & 0.0561 & & 0.7914 & 0.0950 \\
# recording & source & & \textbf{0.9988} & 0.0004 & & 0.9944 & 0.0065 \\
# recording & low & & 0.9828 & 0.0044 & & \textbf{0.9846} & 0.0049 \\
# recording & medium & & 0.9710 & 0.0045 & & \textbf{0.9828} & 0.0138 \\
# recording & high & & 0.9166 & 0.0057 & & \textbf{0.9666} & 0.0086 \\
# release & source & & 0.9810 & 0.0157 & & 0.9810 & 0.0128 \\
# release & low & & \textbf{0.9418} & 0.0422 & & 0.9412 & 0.0449 \\
# release & medium & & \textbf{0.9888} & 0.0039 & & 0.9728 & 0.0059 \\
# release & high & & 0.9776 & 0.0067 & & \textbf{0.9790} & 0.0103 \\
# release_group & source & & \textbf{0.9858} & 0.0049 & & 0.9842 & 0.0057 \\
# release_group & low & & 0.9610 & 0.0027 & & \textbf{0.9658} & 0.0123 \\
# release_group & medium & & 0.9168 & 0.0101 & & \textbf{0.9465} & 0.0165 \\
# release_group & high & & \textbf{0.8246} & 0.0144 & & 0.7832 & 0.2182 \\
# track & source & & \textbf{1.0000} & 0.0000 & & 0.9988 & 0.0018 \\
# track & low & & 0.9986 & 0.0005 & & \textbf{0.9996} & 0.0005 \\
# track & medium & & 0.9964 & 0.0022 & & \textbf{0.9968} & 0.0026 \\
# track & high & & 0.9872 & 0.0016 & & \textbf{0.9914} & 0.0077 \\
# \bottomrule
# \end{tabular}
# \end{table}
#        run_id entity  seed  f1_score  precision  recall  iteration
# 0  9798848_11   area     2     0.650      0.839   0.531          0
# 1  9798848_12   area     3     0.851      0.974   0.755          0
# 2  9798848_10   area     1     0.854      0.950   0.776          0
# 3  9798848_14   area     5     0.889      0.976   0.816          0
#     dataset entity metric_type  f1_score  seed  train_size pollution  epochs
# 0     music   area    baseline     0.990     4         1.0    source      10
# 1     music   area    baseline     0.990     2         1.0    source      10
# 2     music   area    baseline     0.990     1         1.0    source      10
# 3     music   area    baseline     0.990     3         1.0    source      10
# 4     music   area    baseline     0.936     1         1.0       low      10
# ..      ...    ...         ...       ...   ...         ...       ...     ...
# 385   music  track        test     0.996     1         1.0      high      10
# 386   music  track        test     0.996     2         1.0      high      10
# 387   music  track        test     0.995     3         1.0      high      10
# 388   music  track        test     0.978     4         1.0      high      10
# 389   music  track        test     0.992     5         1.0      high      10
#
# [390 rows x 8 columns]

# %% [markdown]
# # 9798848 (MAIN)

# %%
from results_analysis import plot_retem_vs_base, query_metrics_by_config


df = query_metrics(9798848)

latex_code = generate_comparison_latex(df, test_metric='test', dataset_name="imdb")

print(latex_code)

plot_degradation_barplot(df, "music", "main", "roberta")

plot_retem_vs_base(9798848, "Music_main")
# Out:
# \begin{table}[h]
# \centering
# \caption{Main Experiment: Baseline vs. RETEM - Dataset imdb}
# \label{tab:main_exp_}}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{RETEM}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# area & source & & \textbf{0.9802} & 0.0219 & & 0.9618 & 0.0325 \\
# area & low & & \textbf{0.9160} & 0.0274 & & 0.9024 & 0.0836 \\
# area & medium & & 0.6660 & 0.1706 & & \textbf{0.8758} & 0.0336 \\
# area & high & & 0.4986 & 0.1847 & & \textbf{0.6238} & 0.2146 \\
# artist & source & & \textbf{0.9952} & 0.0027 & & 0.9200 & 0.0663 \\
# artist & low & & \textbf{0.9972} & 0.0011 & & 0.8614 & 0.1440 \\
# artist & medium & & \textbf{0.9956} & 0.0009 & & 0.9665 & 0.0272 \\
# artist & high & & \textbf{0.9956} & 0.0026 & & 0.8358 & 0.2082 \\
# artist_credit & source & & 0.9970 & nan & & \textbf{0.9972} & 0.0018 \\
# artist_credit & low & & 0.9900 & 0.0027 & & \textbf{0.9916} & 0.0065 \\
# artist_credit & medium & & 0.9896 & 0.0026 & & \textbf{0.9898} & 0.0034 \\
# artist_credit & high & & \textbf{0.9422} & 0.0094 & & 0.8734 & 0.1818 \\
# label & source & & \textbf{0.9754} & 0.0054 & & 0.9670 & 0.0056 \\
# label & low & & \textbf{0.9540} & 0.0000 & & 0.9368 & 0.0134 \\
# label & medium & & 0.8864 & 0.0071 & & \textbf{0.8898} & 0.0257 \\
# label & high & & 0.7452 & 0.1936 & & \textbf{0.7872} & 0.0793 \\
# medium & source & & 0.8220 & 0.0850 & & \textbf{1.0000} & 0.0000 \\
# medium & low & & 0.9110 & 0.0055 & & \textbf{0.9786} & 0.0083 \\
# medium & medium & & 0.8568 & 0.0102 & & \textbf{0.9898} & 0.0078 \\
# medium & high & & 0.7658 & 0.0294 & & \textbf{0.9624} & 0.0202 \\
# place & source & & \textbf{0.9760} & 0.0022 & & 0.9696 & 0.0065 \\
# place & low & & \textbf{0.9656} & 0.0060 & & 0.9598 & 0.0191 \\
# place & medium & & \textbf{0.9414} & 0.0048 & & 0.9347 & 0.0087 \\
# place & high & & \textbf{0.8692} & 0.0561 & & 0.7914 & 0.0950 \\
# recording & source & & \textbf{0.9988} & 0.0004 & & 0.9944 & 0.0065 \\
# recording & low & & 0.9828 & 0.0044 & & \textbf{0.9846} & 0.0049 \\
# recording & medium & & 0.9710 & 0.0045 & & \textbf{0.9828} & 0.0138 \\
# recording & high & & 0.9166 & 0.0057 & & \textbf{0.9666} & 0.0086 \\
# release & source & & 0.9810 & 0.0157 & & 0.9810 & 0.0128 \\
# release & low & & \textbf{0.9418} & 0.0422 & & 0.9412 & 0.0449 \\
# release & medium & & \textbf{0.9888} & 0.0039 & & 0.9728 & 0.0059 \\
# release & high & & 0.9776 & 0.0067 & & \textbf{0.9790} & 0.0103 \\
# release_group & source & & \textbf{0.9858} & 0.0049 & & 0.9842 & 0.0057 \\
# release_group & low & & 0.9610 & 0.0027 & & \textbf{0.9658} & 0.0123 \\
# release_group & medium & & 0.9168 & 0.0101 & & \textbf{0.9465} & 0.0165 \\
# release_group & high & & \textbf{0.8246} & 0.0144 & & 0.7832 & 0.2182 \\
# track & source & & \textbf{1.0000} & 0.0000 & & 0.9988 & 0.0018 \\
# track & low & & 0.9986 & 0.0005 & & \textbf{0.9996} & 0.0005 \\
# track & medium & & 0.9964 & 0.0022 & & \textbf{0.9968} & 0.0026 \\
# track & high & & 0.9872 & 0.0016 & & \textbf{0.9914} & 0.0077 \\
# \bottomrule
# \end{tabular}
# \end{table}
#           job_id  retem_f1  baseline_f1 pollution  f1_diff
# 0      9798848_3     1.000        0.784    source    0.216
# 1      9798848_3     1.000        0.973    source    0.027
# 2      9798848_3     1.000        0.975    source    0.025
# 3      9798848_3     1.000        0.988    source    0.012
# 4      9798848_3     1.000        0.988    source    0.012
# ...          ...       ...          ...       ...      ...
# 1895  9798848_19     0.853        0.925      high   -0.072
# 1896  9798848_19     0.853        0.949      high   -0.096
# 1897  9798848_19     0.853        0.977      high   -0.124
# 1898  9798848_19     0.853        0.990      high   -0.137
# 1899  9798848_19     0.853        0.998      high   -0.145
#
# [1900 rows x 5 columns]

# %%
df_nan_sd = query_metrics_by_config(9798848, "source", "artist_credit")
display(df_nan_sd)
# Out:
#   dataset         entity metric_type  f1_score  seed  train_size pollution  \
# 0   music  artist_credit    baseline     0.997     4         1.0    source
# 1   music  artist_credit    baseline     0.997     2         1.0    source
# 2   music  artist_credit    baseline     0.997     3         1.0    source
# 3   music  artist_credit    baseline     0.997     1         1.0    source
# 4   music  artist_credit    baseline     0.997     5         1.0    source
# 5   music  artist_credit        test     0.997     4         1.0    source
# 6   music  artist_credit        test     0.997     3         1.0    source
# 7   music  artist_credit        test     1.000     2         1.0    source
# 8   music  artist_credit        test     0.995     1         1.0    source
# 9   music  artist_credit        test     0.997     5         1.0    source
#
#    batch_size  max_len  learning_rate  epochs       lm  neg_ratio
# 0          32      512        0.00003      10  roberta          0
# 1          32      512        0.00003      10  roberta          0
# 2          32      512        0.00003      10  roberta          0
# 3          32      512        0.00003      10  roberta          0
# 4          32      512        0.00003      10  roberta          0
# 5          32      512        0.00003      10  roberta          0
# 6          32      512        0.00003      10  roberta          0
# 7          32      512        0.00003      10  roberta          0
# 8          32      512        0.00003      10  roberta          0
# 9          32      512        0.00003      10  roberta          0

# %%
# Recalculate SD

import statistics

data = [0.99, 
        0.99,
        0.99, 
        0.99, 
        0.941]

# Sample standard deviation
sample_sd = statistics.stdev(data)
print(f"Sample SD: {sample_sd}")
# Out:
# Sample SD: 0.021913466179497958

# %%
from analyze_val_scores import process_directory
jobid = 9798848

df = process_directory("../slurm_logs", jobid)

display(df)
# Out:
# threshold for val f1: 0.9920
#             entity       val  baseline   test  baseline_is_higher
# 38   release_group  0.400000     0.959  0.954                   1
# 60            area  0.400000     0.990  0.911                   1
# 98   release_group  0.400000     0.988  0.988                   0
# 123          label  0.400000     0.400  0.769                   0
# 130           area  0.401709     0.400  0.733                   0
# ..             ...       ...       ...    ...                 ...
# 77         release  1.000000     0.988  0.974                   1
# 76       recording  1.000000     0.999  0.995                   1
# 72   artist_credit  1.000000     0.997  0.997                   0
# 92   artist_credit  1.000000     0.997  0.995                   1
# 199          track  1.000000     0.995    NaN                   0
#
# [200 rows x 5 columns]

# %% [markdown]
# # 9806715

# %%
df = query_metrics(9806715)

latex_code = generate_comparison_latex(df, test_metric='test', dataset_name="imdb")

print(latex_code)

plot_degradation_barplot(df, "music", "main", "roberta")

threshold = 0.05

df = query_metrics_p1(9806715)

# Filter the aggregated dataframe to find problematic configurations
high_sd_df = df[df['std_f1'] > threshold].copy()

print(f"Found {len(high_sd_df)} rows with Standard Deviation > {threshold}")
display(high_sd_df)
# Out:
# \begin{table}[h]
# \centering
# \caption{Main Experiment: Baseline vs. RETEM - Dataset imdb}
# \label{tab:main_exp_}}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{RETEM}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# area & source & & 0.6670 & nan & & \textbf{0.7320} & 0.2529 \\
# area & low & & 0.4387 & 0.2194 & & \textbf{0.6780} & 0.3274 \\
# area & medium & & 0.4760 & 0.0797 & & \textbf{0.4987} & 0.2379 \\
# area & high & & \textbf{0.4000} & nan & & 0.2853 & 0.1530 \\
# artist & source & & \textbf{0.5090} & nan & & 0.3913 & 0.0764 \\
# artist & low & & 0.3713 & 0.0289 & & \textbf{0.3880} & 0.0208 \\
# artist & medium & & 0.3567 & 0.0722 & & \textbf{0.3897} & 0.0224 \\
# artist & high & & \textbf{0.4150} & 0.0260 & & 0.3777 & 0.1128 \\
# artist_credit & source & & 0.8540 & 0.0000 & & \textbf{0.8757} & 0.0975 \\
# artist_credit & low & & 0.6293 & 0.1045 & & \textbf{0.6583} & 0.2187 \\
# artist_credit & medium & & 0.3293 & 0.1224 & & \textbf{0.5337} & 0.3199 \\
# artist_credit & high & & \textbf{0.4253} & 0.0439 & & 0.2503 & 0.2041 \\
# label & source & & 0.6510 & 0.0000 & & \textbf{0.8163} & 0.1727 \\
# label & low & & 0.5860 & 0.1074 & & \textbf{0.7977} & 0.1176 \\
# label & medium & & \textbf{0.6820} & 0.2442 & & 0.6143 & 0.1923 \\
# label & high & & 0.5167 & 0.1010 & & \textbf{0.6037} & 0.0720 \\
# medium & source & & 0.8000 & nan & & \textbf{0.9733} & 0.0107 \\
# medium & low & & 0.7000 & 0.1680 & & \textbf{0.8193} & 0.1416 \\
# medium & medium & & 0.5980 & 0.1420 & & \textbf{0.6837} & 0.2137 \\
# medium & high & & 0.4547 & 0.0687 & & \textbf{0.7177} & 0.0525 \\
# place & source & & 0.4010 & 0.0000 & & \textbf{0.7353} & 0.2103 \\
# place & low & & 0.5813 & 0.0664 & & \textbf{0.6823} & 0.1772 \\
# place & medium & & 0.4623 & 0.0064 & & \textbf{0.5970} & 0.1820 \\
# place & high & & \textbf{0.6053} & 0.0612 & & 0.4947 & 0.0842 \\
# recording & source & & 0.3960 & nan & & \textbf{0.5920} & 0.3369 \\
# recording & low & & 0.3973 & 0.0023 & & \textbf{0.6790} & 0.2589 \\
# recording & medium & & \textbf{0.3967} & 0.0029 & & 0.3360 & 0.1109 \\
# recording & high & & 0.3987 & 0.0006 & & \textbf{0.4793} & 0.1092 \\
# release & source & & 0.4000 & nan & & \textbf{0.6620} & 0.2269 \\
# release & low & & 0.4230 & 0.0208 & & \textbf{0.6100} & 0.1971 \\
# release & medium & & 0.4047 & 0.0040 & & \textbf{0.5483} & 0.2578 \\
# release & high & & 0.4000 & nan & & \textbf{0.5493} & 0.2587 \\
# release_group & source & & 0.5670 & 0.0000 & & \textbf{0.5897} & 0.1669 \\
# release_group & low & & \textbf{0.4057} & 0.0058 & & 0.3173 & 0.0846 \\
# release_group & medium & & \textbf{0.3917} & 0.0006 & & 0.3463 & 0.2708 \\
# release_group & high & & \textbf{0.3033} & 0.1674 & & 0.2723 & 0.2255 \\
# track & source & & 0.9730 & nan & & \textbf{0.9960} & 0.0026 \\
# track & low & & 0.7173 & 0.0006 & & \textbf{0.9877} & 0.0047 \\
# track & medium & & \textbf{0.9197} & 0.0167 & & 0.8027 & 0.2704 \\
# track & high & & 0.4117 & 0.0219 & & \textbf{0.7093} & 0.2623 \\
# \bottomrule
# \end{tabular}
# \end{table}
# Found 20 rows with Standard Deviation > 0.05
#    dataset         entity metric_type   mean_f1    std_f1  num_seeds  \
# 1    music           area      phase1  0.578000  0.181601          3
# 2    music           area      phase1  0.498333  0.093874          3
# 3    music           area      phase1  0.564333  0.186979          3
# 9    music  artist_credit      phase1  0.492333  0.080314          3
# 13   music          label      phase1  0.568000  0.145506          3
# 14   music          label      phase1  0.503333  0.178979          3
# 15   music          label      phase1  0.492333  0.157335          3
# 17   music         medium      phase1  0.547333  0.249167          3
# 18   music         medium      phase1  0.505667  0.182155          3
# 19   music         medium      phase1  0.654667  0.222756          3
# 21   music          place      phase1  0.492333  0.095039          3
# 22   music          place      phase1  0.481667  0.088715          3
# 23   music          place      phase1  0.492000  0.136077          3
# 24   music      recording      phase1  0.294000  0.182732          3
# 25   music      recording      phase1  0.341333  0.100749          3
# 31   music        release      phase1  0.509000  0.189660          3
# 35   music  release_group      phase1  0.342000  0.119616          3
# 37   music          track      phase1  0.683000  0.203620          3
# 38   music          track      phase1  0.572667  0.269147          3
# 39   music          track      phase1  0.758000  0.246051          3
#
#     train_size pollution  epochs
# 1        0.125       low      10
# 2        0.125    medium      10
# 3        0.125    source      10
# 9        0.125       low      10
# 13       0.125       low      10
# 14       0.125    medium      10
# 15       0.125    source      10
# 17       0.125       low      10
# 18       0.125    medium      10
# 19       0.125    source      10
# 21       0.125       low      10
# 22       0.125    medium      10
# 23       0.125    source      10
# 24       0.125      high      10
# 25       0.125       low      10
# 31       0.125    source      10
# 35       0.125    source      10
# 37       0.125       low      10
# 38       0.125    medium      10
# 39       0.125    source      10

# %%
df_nan_sd = query_metrics_by_config(9806715, "source", "track")
display(df_nan_sd)
# Out:
#   dataset entity metric_type  f1_score  seed  train_size pollution  \
# 0   music  track    baseline     0.973     3       0.125    source
# 1   music  track    baseline     0.973     2       0.125    source
# 2   music  track    baseline     0.973     1       0.125    source
# 3   music  track        test     0.997     2       0.125    source
# 4   music  track        test     0.993     1       0.125    source
# 5   music  track        test     0.998     3       0.125    source
#
#    batch_size  max_len  learning_rate  epochs       lm  neg_ratio
# 0          32      512        0.00003      10  roberta          0
# 1          32      512        0.00003      10  roberta          0
# 2          32      512        0.00003      10  roberta          0
# 3          32      512        0.00003      10  roberta          0
# 4          32      512        0.00003      10  roberta          0
# 5          32      512        0.00003      10  roberta          0

# %%
# Recalculate SD

import statistics

data = [0.99, 
        0.99,
        0.99, 
        0.99, 
        0.941]

# Sample standard deviation
sample_sd = statistics.stdev(data)
print(f"Sample SD: {sample_sd}")

# %%
from results_analysis import plot_retem_vs_base


plot_retem_vs_base(9806715, "Music")
# Out:
#           job_id  retem_f1  baseline_f1 pollution  f1_diff
# 0      9806715_3     0.986        0.338       low    0.648
# 1      9806715_3     0.986        0.399       low    0.587
# 2      9806715_3     0.986        0.399       low    0.587
# 3      9806715_3     0.986        0.400       low    0.586
# 4      9806715_3     0.986        0.462       low    0.524
# ...          ...       ...          ...       ...      ...
# 1195  9806715_11     0.399        0.400      high   -0.001
# 1196  9806715_11     0.399        0.400      high   -0.001
# 1197  9806715_11     0.399        0.415      high   -0.016
# 1198  9806715_11     0.399        0.570      high   -0.171
# 1199  9806715_11     0.399        0.575      high   -0.176
#
# [1200 rows x 5 columns]

# %%
from results_analysis import generate_comparison_latex_prelim, query_prelimary

df = query_prelimary(9798848)

latex_code = generate_comparison_latex_prelim(df, "Music")

print(latex_code)

# plot_degradation_barplot(df, "imdb", "prelim", "roberta")
# Out:
# \begin{table}[h]
# \centering
# \caption{Baseline (Ditto pure) vs. Phase 1 (Empty Relational Scores) vs. Phase 2 (Relational Scores based on Ground-Truth) - Dataset Music}
# \label{tab:prelim_exp_}
# \begin{tabular}{ll c cc c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{Phase 1}} & & \multicolumn{2}{c}{\textbf{Phase 2}} \\
# \cmidrule{4-5} \cmidrule{7-8} \cmidrule{10-11}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} \\
# \midrule
# area & source & & \textbf{0.9802} & 0.0219 & & 0.9246 & 0.0894 & & 0.9602 & 0.0264 \\
# area & low & & \textbf{0.9160} & 0.0274 & & 0.7944 & 0.2209 & & 0.9060 & 0.0831 \\
# area & medium & & 0.6660 & 0.1706 & & 0.8110 & 0.1087 & & \textbf{0.8665} & 0.0303 \\
# area & high & & 0.4986 & 0.1847 & & 0.4692 & 0.1799 & & \textbf{0.6672} & 0.2448 \\
# artist & source & & 0.9952 & 0.0027 & & 0.9960 & 0.0032 & & \textbf{0.9972} & 0.0027 \\
# artist & low & & 0.9972 & 0.0011 & & \textbf{0.9980} & 0.0020 & & \textbf{0.9980} & 0.0014 \\
# artist & medium & & 0.9956 & 0.0009 & & 0.9975 & 0.0019 & & \textbf{0.9980} & 0.0016 \\
# artist & high & & \textbf{0.9956} & 0.0026 & & 0.9880 & 0.0026 & & 0.9932 & 0.0041 \\
# artist_credit & source & & \textbf{0.9970} & nan & & 0.9900 & 0.0054 & & 0.9968 & 0.0020 \\
# artist_credit & low & & 0.9900 & 0.0027 & & \textbf{0.9924} & 0.0026 & & 0.9914 & 0.0090 \\
# artist_credit & medium & & \textbf{0.9896} & 0.0026 & & 0.9840 & 0.0050 & & 0.9892 & 0.0029 \\
# artist_credit & high & & 0.9422 & 0.0094 & & 0.9496 & 0.0031 & & \textbf{0.9792} & 0.0131 \\
# label & source & & \textbf{0.9754} & 0.0054 & & 0.9714 & 0.0121 & & 0.9712 & 0.0050 \\
# label & low & & \textbf{0.9540} & 0.0000 & & 0.9480 & 0.0034 & & 0.9536 & 0.0108 \\
# label & medium & & 0.8864 & 0.0071 & & \textbf{0.8890} & 0.0168 & & 0.8882 & 0.0149 \\
# label & high & & 0.7452 & 0.1936 & & 0.5872 & 0.2155 & & \textbf{0.8164} & 0.0699 \\
# medium & source & & 0.8220 & 0.0850 & & 0.9728 & 0.0016 & & \textbf{0.9992} & 0.0018 \\
# medium & low & & 0.9110 & 0.0055 & & 0.9032 & 0.0040 & & \textbf{0.9686} & 0.0095 \\
# medium & medium & & 0.8568 & 0.0102 & & 0.8658 & 0.0112 & & \textbf{0.9800} & 0.0038 \\
# medium & high & & 0.7658 & 0.0294 & & 0.6848 & 0.1595 & & \textbf{0.9656} & 0.0196 \\
# place & source & & 0.9760 & 0.0022 & & \textbf{0.9768} & 0.0080 & & 0.9628 & 0.0211 \\
# place & low & & 0.9656 & 0.0060 & & 0.9492 & 0.0284 & & \textbf{0.9680} & 0.0117 \\
# place & medium & & \textbf{0.9414} & 0.0048 & & 0.9287 & 0.0273 & & 0.9390 & 0.0081 \\
# place & high & & 0.8692 & 0.0561 & & \textbf{0.8944} & 0.0151 & & 0.8920 & 0.0144 \\
# recording & source & & \textbf{0.9988} & 0.0004 & & 0.9960 & 0.0027 & & 0.9968 & 0.0028 \\
# recording & low & & 0.9828 & 0.0044 & & 0.8660 & 0.2606 & & \textbf{0.9848} & 0.0058 \\
# recording & medium & & \textbf{0.9710} & 0.0045 & & 0.9667 & 0.0031 & & 0.9705 & 0.0062 \\
# recording & high & & 0.9166 & 0.0057 & & 0.9192 & 0.0137 & & \textbf{0.9498} & 0.0042 \\
# release & source & & 0.9810 & 0.0157 & & 0.9822 & 0.0194 & & \textbf{0.9912} & 0.0051 \\
# release & low & & 0.9418 & 0.0422 & & 0.9830 & 0.0030 & & \textbf{0.9866} & 0.0051 \\
# release & medium & & 0.9888 & 0.0039 & & 0.9840 & 0.0051 & & \textbf{0.9898} & 0.0048 \\
# release & high & & 0.9776 & 0.0067 & & 0.9810 & 0.0061 & & \textbf{0.9898} & 0.0038 \\
# release_group & source & & \textbf{0.9858} & 0.0049 & & 0.9780 & 0.0120 & & 0.9830 & 0.0041 \\
# release_group & low & & 0.9610 & 0.0027 & & 0.9564 & 0.0030 & & \textbf{0.9644} & 0.0133 \\
# release_group & medium & & 0.9168 & 0.0101 & & 0.9175 & 0.0108 & & \textbf{0.9577} & 0.0082 \\
# release_group & high & & \textbf{0.8246} & 0.0144 & & 0.6342 & 0.2153 & & 0.8034 & 0.2258 \\
# track & source & & \textbf{1.0000} & 0.0000 & & 0.9982 & 0.0015 & & 0.9988 & 0.0018 \\
# track & low & & 0.9986 & 0.0005 & & 0.9982 & 0.0015 & & \textbf{0.9992} & 0.0008 \\
# track & medium & & \textbf{0.9964} & 0.0022 & & 0.9945 & 0.0079 & & 0.9960 & 0.0027 \\
# track & high & & 0.9872 & 0.0016 & & 0.9848 & 0.0027 & & \textbf{0.9938} & 0.0025 \\
# \bottomrule
# \end{tabular}
# \end{table}
