# %% [markdown]
# # JOB ID: 9790002
#
# Dataset: IMDB
#
# Trainset size: Full
#
# Pollutions: source, low, medium, high
#
# lm: roberta

# %% [markdown]
# ## Main Results

# %%
from results_analysis import generate_comparison_latex, plot_degradation_barplot, plot_degradation_boxplot, query_metrics, query_metrics_individual
import pandas as pd

df = query_metrics(9790002)

latex_code = generate_comparison_latex(df, test_metric='test')

print(latex_code)

plot_degradation_barplot(df, "imdb", "main", "roberta")

# df = query_metrics_individual(9790002)

# plot_degradation_boxplot(df, "imdb", "main", "roberta")
# Out:
# \begin{table}[h]
# \centering
# \caption{Main Experiment: Baseline vs. RETEM - Dataset music}
# \label{tab:main_exp_}}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{RETEM}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# movie & source & & 0.9984 & 0.0009 & & \textbf{0.9992} & 0.0008 \\
# movie & low & & 0.9627 & 0.0055 & & \textbf{0.9734} & 0.0058 \\
# movie & medium & & 0.9282 & 0.0078 & & \textbf{0.9480} & 0.0050 \\
# movie & high & & 0.8294 & 0.0056 & & \textbf{0.9158} & 0.0122 \\
# name & source & & \textbf{0.9994} & 0.0013 & & 0.9974 & 0.0021 \\
# name & low & & \textbf{0.9968} & 0.0005 & & 0.9952 & 0.0015 \\
# name & medium & & 0.9580 & 0.0042 & & \textbf{0.9820} & 0.0050 \\
# name & high & & 0.9188 & 0.0110 & & \textbf{0.9740} & 0.0099 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# ## Scatterplot Difference

# %%
from results_analysis import plot_retem_vs_base

df = plot_retem_vs_base(9790002, "IMDB")

display(df)
# Out:
#         job_id  retem_f1  baseline_f1 pollution  f1_diff
# 0    9790002_3     0.998        0.998    source    0.000
# 1    9790002_3     0.998        1.000    source   -0.002
# 2    9790002_0     1.000        0.998    source    0.002
# 3    9790002_0     1.000        1.000    source    0.000
# 4    9790002_2     1.000        0.998    source    0.002
# ..         ...       ...          ...       ...      ...
# 67  9790002_18     0.984        0.900      high    0.084
# 68  9790002_19     0.896        0.838      high    0.058
# 69  9790002_19     0.896        0.918      high   -0.022
# 70  9790002_19     0.981        0.838      high    0.143
# 71  9790002_19     0.981        0.918      high    0.063
#
# [72 rows x 5 columns]

# %%
from analyze_val_scores import process_directory
jobid = 9790002

df = process_directory("../slurm_logs", jobid)

display(df)
# Out:
# threshold for val f1: 0.9900
#    entity       val  baseline   test  baseline_is_higher
# 36  movie  0.836237     0.827  0.916                   0
# 0   movie  0.839506     0.832  0.916                   0
# 2   movie  0.843786     0.825  0.923                   0
# 6   movie  0.846765     0.825  0.928                   0
# 38  movie  0.847875     0.838  0.896                   0
# 37   name  0.909747     0.900  0.984                   0
# 1    name  0.910959     0.926  0.977                   0
# 39   name  0.911661     0.918  0.981                   0
# 3    name  0.916364     0.925  0.960                   0
# 7    name  0.921986     0.925  0.968                   0
# 12  movie  0.929271     0.915    NaN                   0
# 8   movie  0.940552     0.929  0.942                   0
# 14  movie  0.941302     0.934  0.949                   0
# 4   movie  0.943436     0.934  0.947                   0
# 10  movie  0.944152     0.929  0.954                   0
# 5    name  0.972414     0.962  0.987                   0
# 9    name  0.972603     0.957  0.983                   0
# 13   name  0.976271     0.952    NaN                   0
# 15   name  0.976431     0.962  0.983                   0
# 30  movie  0.979167     0.960  0.981                   0
# 11   name  0.979592     0.957  0.975                   0
# 24  movie  0.982383     0.960  0.971                   0
# 26  movie  0.982383     0.960  0.969                   0
# 32  movie  0.983437     0.971  0.978                   0
# 27   name  0.996587     0.997  0.997                   0
# 33   name  0.996587     0.996  0.995                   1
# 31   name  0.996587     0.997  0.995                   1
# 25   name  0.996587     0.997  0.996                   1
# 29   name  1.000000     0.997  0.995                   1
# 22  movie  1.000000     0.998  0.998                   0
# 23   name  1.000000     1.000  0.996                   1
# 21   name  1.000000     1.000  1.000                   0
# 20  movie  1.000000     0.998  1.000                   0
# 19   name  1.000000     1.000  0.997                   1
# 17   name  1.000000     1.000  0.999                   1
# 16  movie  1.000000     0.998  0.999                   0
# 28  movie  1.000000     1.000  0.999                   1
# 18  movie  1.000000     0.998  1.000                   0
# 34  movie       NaN       NaN  0.968                   0
# 35   name       NaN       NaN  0.993                   0

# %% [markdown]
# ## IMDB Prelim

# %%
from results_analysis import generate_comparison_latex_prelim, query_prelimary

df = query_prelimary(9790002)

latex_code = generate_comparison_latex_prelim(df, "imdb")

print(latex_code)

plot_degradation_barplot(df, "imdb", "prelim", "roberta")
# Out:
# \begin{table}[h]
# \centering
# \caption{Baseline (Ditto pure) vs. Phase 1 (Empty Relational Scores) vs. Phase 2 (Relational Scores based on Ground-Truth) - Dataset imdb}
# \label{tab:prelim_exp_}
# \begin{tabular}{ll c cc c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{Phase 1}} & & \multicolumn{2}{c}{\textbf{Phase 2}} \\
# \cmidrule{4-5} \cmidrule{7-8} \cmidrule{10-11}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} \\
# \midrule
# movie & source & & 0.9984 & 0.0009 & & \textbf{0.9990} & 0.0007 & & 0.9988 & 0.0016 \\
# movie & low & & 0.9627 & 0.0055 & & 0.9702 & 0.0043 & & \textbf{0.9730} & 0.0039 \\
# movie & medium & & 0.9282 & 0.0078 & & 0.9243 & 0.0060 & & \textbf{0.9475} & 0.0047 \\
# movie & high & & 0.8294 & 0.0056 & & 0.8352 & 0.0052 & & \textbf{0.9054} & 0.0050 \\
# name & source & & \textbf{0.9994} & 0.0013 & & 0.9980 & 0.0019 & & 0.9970 & 0.0023 \\
# name & low & & \textbf{0.9968} & 0.0005 & & 0.9946 & 0.0017 & & 0.9952 & 0.0024 \\
# name & medium & & 0.9580 & 0.0042 & & 0.9597 & 0.0048 & & \textbf{0.9835} & 0.0019 \\
# name & high & & 0.9188 & 0.0110 & & 0.9252 & 0.0056 & & \textbf{0.9818} & 0.0015 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# # JOB ID: 9790670
#
# Dataset: IMDB
#
# Trainset size: Full
#
# Pollutions: source, low, medium, high
#
# lm: distillbert

# %% [markdown]
# ## Main

# %%
df = query_metrics(9790670)

latex_code = generate_comparison_latex(df, test_metric='test')

print(latex_code)

plot_degradation_barplot(df, "imdb", "main", "roberta")

# df = query_metrics_individual(9790002)

# plot_degradation_boxplot(df, "imdb", "main", "roberta")
# Out:
# \begin{table}[h]
# \centering
# \caption{Main Experiment: Baseline vs. RETEM - Dataset music}
# \label{tab:main_exp_}}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{RETEM}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# movie & source & & 0.9972 & 0.0004 & & \textbf{0.9974} & 0.0005 \\
# movie & low & & 0.9704 & 0.0015 & & \textbf{0.9716} & 0.0052 \\
# movie & medium & & 0.9144 & 0.0033 & & \textbf{0.9434} & 0.0111 \\
# movie & high & & 0.7976 & 0.0009 & & \textbf{0.9014} & 0.0090 \\
# name & source & & 0.9970 & nan & & \textbf{0.9988} & 0.0011 \\
# name & low & & 0.9904 & 0.0019 & & \textbf{0.9954} & 0.0029 \\
# name & medium & & 0.9512 & 0.0020 & & \textbf{0.9688} & 0.0108 \\
# name & high & & 0.8826 & 0.0043 & & \textbf{0.9292} & 0.0157 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# ## ScatterPlot

# %%
from results_analysis import plot_retem_vs_base


plot_retem_vs_base(9790670)

# %% [markdown]
# ## Prelim

# %%
df = query_prelimary(9790670)

latex_code = generate_comparison_latex_prelim(df, "imdb")

print(latex_code)

plot_degradation_barplot(df, "imdb", "prelim", "roberta")
# Out:
# \begin{table}[h]
# \centering
# \caption{Baseline (Ditto pure) vs. Phase 1 (Empty Relational Scores) vs. Phase 2 (Relational Scores based on Ground-Truth) - Dataset imdb}
# \label{tab:prelim_exp_}
# \begin{tabular}{ll c cc c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{Phase 1}} & & \multicolumn{2}{c}{\textbf{Phase 2}} \\
# \cmidrule{4-5} \cmidrule{7-8} \cmidrule{10-11}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} \\
# \midrule
# movie & source & & 0.9972 & 0.0004 & & 0.9970 & 0.0012 & & \textbf{0.9974} & 0.0005 \\
# movie & low & & 0.9704 & 0.0015 & & 0.9678 & 0.0019 & & \textbf{0.9712} & 0.0050 \\
# movie & medium & & 0.9144 & 0.0033 & & 0.9144 & 0.0051 & & \textbf{0.9448} & 0.0045 \\
# movie & high & & 0.7976 & 0.0009 & & 0.7980 & 0.0043 & & \textbf{0.8902} & 0.0041 \\
# name & source & & 0.9970 & nan & & 0.9986 & 0.0015 & & \textbf{0.9988} & 0.0011 \\
# name & low & & 0.9904 & 0.0019 & & 0.9916 & 0.0013 & & \textbf{0.9958} & 0.0022 \\
# name & medium & & 0.9512 & 0.0020 & & 0.9568 & 0.0060 & & \textbf{0.9870} & 0.0031 \\
# name & high & & 0.8826 & 0.0043 & & 0.8808 & 0.0069 & & \textbf{0.9724} & 0.0032 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# # 9805197
#
# Roberta
#
# 2e-5
#
# trainsize = 125

# %%
df = query_metrics(9805197)

latex_code = generate_comparison_latex(df, test_metric='test', dataset_name="imdb")

print(latex_code)

plot_degradation_barplot(df, "imdb", "main", "roberta")

# df = query_metrics_individual(9790002)

# plot_degradation_boxplot(df, "imdb", "main", "roberta")
# Out:
# \begin{table}[h]
# \centering
# \caption{Main Experiment: Baseline vs. RETEM - Dataset imdb}
# \label{tab:main_exp_}}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{RETEM}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# movie & source & & 0.9830 & 0.0000 & & \textbf{0.9940} & 0.0056 \\
# movie & low & & 0.7977 & 0.1010 & & \textbf{0.9283} & 0.0529 \\
# movie & medium & & 0.4207 & 0.0179 & & \textbf{0.7980} & 0.1742 \\
# movie & high & & 0.4417 & 0.0352 & & \textbf{0.5283} & 0.1655 \\
# name & source & & 0.4170 & 0.0000 & & \textbf{0.9920} & 0.0070 \\
# name & low & & 0.9087 & 0.0092 & & \textbf{0.9173} & 0.1155 \\
# name & medium & & 0.5687 & 0.0699 & & \textbf{0.7290} & 0.2812 \\
# name & high & & 0.5257 & 0.1080 & & \textbf{0.6270} & 0.1506 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# ## Scatterplot

# %%
df = plot_retem_vs_base(9805197, "IMDB")

display(df)
# Out:
#         job_id  retem_f1  baseline_f1 pollution  f1_diff
# 0    9805197_3     0.967        0.681       low    0.286
# 1    9805197_3     0.967        0.898       low    0.069
# 2    9805197_2     0.995        0.417    source    0.578
# 3    9805197_2     0.995        0.983    source    0.012
# 4    9805197_1     0.988        0.417    source    0.571
# 5    9805197_1     0.988        0.983    source    0.005
# 6    9805197_0     0.999        0.417    source    0.582
# 7    9805197_0     0.999        0.983    source    0.016
# 8    9805197_3     0.986        0.681       low    0.305
# 9    9805197_3     0.986        0.898       low    0.088
# 10   9805197_2     0.997        0.417    source    0.580
# 11   9805197_2     0.997        0.983    source    0.014
# 12   9805197_1     0.995        0.417    source    0.578
# 13   9805197_1     0.995        0.983    source    0.012
# 14   9805197_0     0.984        0.417    source    0.567
# 15   9805197_0     0.984        0.983    source    0.001
# 16   9805197_7     0.892        0.431    medium    0.461
# 17   9805197_7     0.892        0.609    medium    0.283
# 18   9805197_6     0.905        0.431    medium    0.474
# 19   9805197_6     0.905        0.609    medium    0.296
# 20   9805197_4     0.950        0.856       low    0.094
# 21   9805197_4     0.950        0.914       low    0.036
# 22   9805197_7     0.910        0.431    medium    0.479
# 23   9805197_7     0.910        0.609    medium    0.301
# 24   9805197_6     0.872        0.431    medium    0.441
# 25   9805197_6     0.872        0.609    medium    0.263
# 26   9805197_4     0.982        0.856       low    0.126
# 27   9805197_4     0.982        0.914       low    0.068
# 28   9805197_5     0.868        0.856       low    0.012
# 29   9805197_5     0.868        0.914       low   -0.046
# 30   9805197_5     0.784        0.856       low   -0.072
# 31   9805197_5     0.784        0.914       low   -0.130
# 32   9805197_8     0.597        0.400    medium    0.197
# 33   9805197_8     0.597        0.488    medium    0.109
# 34   9805197_9     0.403        0.462      high   -0.059
# 35   9805197_9     0.403        0.588      high   -0.185
# 36   9805197_9     0.458        0.462      high   -0.004
# 37   9805197_9     0.458        0.588      high   -0.130
# 38   9805197_8     0.405        0.400    medium    0.005
# 39   9805197_8     0.405        0.488    medium   -0.083
# 40  9805197_10     0.716        0.462      high    0.254
# 41  9805197_10     0.716        0.588      high    0.128
# 42  9805197_10     0.676        0.462      high    0.214
# 43  9805197_10     0.676        0.588      high    0.088
# 44  9805197_11     0.466        0.401      high    0.065
# 45  9805197_11     0.466        0.401      high    0.065
# 46  9805197_11     0.747        0.401      high    0.346
# 47  9805197_11     0.747        0.401      high    0.346

# %%
from analyze_val_scores import process_directory
jobid = 9805197

df = process_directory("../slurm_logs", jobid)

display(df)

# df = pd.DataFrame(data, columns=["entity", "val", "baseline", "test"])

# # Target variable: 1 if baseline > test, else 0
# df["baseline_is_higher"] = (df["baseline"] > df["test"]).astype(int)

# df_sorted = df.sort_values(by=["val"])
# display(df_sorted)

# # Fit a shallow decision tree
# X = df[["val"]]
# y = df["baseline_is_higher"]

# # max_depth=1 forces the tree to find exactly one optimal splitting threshold
# tree = DecisionTreeClassifier(max_depth=1)
# tree.fit(X, y)

# # Extract the threshold
# threshold = tree.tree_.threshold[0]
# print(f"The mathematically optimal threshold for 'val' is: {threshold:.4f}")
# Out:
# threshold for val f1: 0.6570
#    entity       val  baseline   test  baseline_is_higher
# 16  movie  0.400000     0.462  0.716                   0
# 0   movie  0.400164     0.400  0.597                   0
# 22  movie  0.402138     0.401  0.466                   0
# 17   name  0.403042     0.588  0.676                   0
# 20  movie  0.406939     0.431  0.905                   0
# 23   name  0.408428     0.401  0.747                   0
# 14  movie  0.412892     0.856  0.868                   0
# 18  movie  0.415179     0.431  0.892                   0
# 5    name  0.430976     0.417  0.997                   0
# 2   movie  0.436081     0.462  0.403                   1
# 1    name  0.516129     0.488  0.405                   1
# 3    name  0.563158     0.588  0.458                   1
# 21   name  0.575893     0.609  0.872                   0
# 15   name  0.626374     0.914  0.784                   1
# 6   movie  0.687552     0.681  0.967                   0
# 11   name  0.797721     0.417  0.984                   0
# 4   movie  0.822868     0.983  0.995                   0
# 13   name  0.839858     0.914  0.982                   0
# 7    name  0.842491     0.898  0.986                   0
# 19   name  0.897260     0.609  0.910                   0
# 12  movie  0.927879     0.856  0.950                   0
# 9    name  0.966887     0.417  0.995                   0
# 8   movie  0.982492     0.983  0.988                   0
# 10  movie  0.984488     0.983  0.999                   0

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

df = pd.DataFrame(data, columns=["entity", "val", "baseline", "test"])

# 2. Sort data by 'val' so line charts plot smoothly
df = df.sort_values(by="val")

# 3. Initialize the plot style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))

# 4. Plot actual data points (Scatter)
plt.scatter(
    df["val"],
    df["baseline"],
    color="#4C72B0",
    alpha=0.6,
    label="Baseline Scores",
    edgecolors="w",
    s=80,
)
plt.scatter(
    df["val"],
    df["test"],
    color="#DD8452",
    alpha=0.6,
    label="Test Scores",
    edgecolors="w",
    s=80,
)

# # 5. Add Trend Lines (Linear Regression or smooth Lowess)
# # Using a simple linear fit here to show overarching influence
# sns.regplot(
#     data=df,
#     x="val",
#     y="baseline",
#     scatter=False,
#     color="#4C72B0",
#     label="Baseline Trend",
#     line_kws={"linestyle": "--"},
# )
# sns.regplot(
#     data=df,
#     x="val",
#     y="test",
#     scatter=False,
#     color="#DD8452",
#     label="Test Trend",
# )

# 6. Formatting titles, legends, and axes
plt.title(
    "Influence of Validation Score on Baseline vs. Test Performance",
    fontsize=14,
    pad=15,
)
plt.xlabel("Validation Score (val)", fontsize=12)
plt.ylabel("F1 Score", fontsize=12)
plt.ylim(0, 1)  # Constrain axis slightly to focus on the data spread
plt.legend(frameon=True, facecolor="white", edgecolor="none")

# Optional: If you find an exact threshold 't', you can draw a vertical line:
# plt.axvline(x=0.55, color='red', linestyle=':', label='Threshold (t)')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 6
#       3 import pandas as pd
#       4 import seaborn as sns
# ----> 6 df = pd.DataFrame(data, columns=["entity", "val", "baseline", "test"])
#       8 # 2. Sort data by 'val' so line charts plot smoothly
#       9 df = df.sort_values(by="val")
#
# NameError: name 'data' is not defined

# %% [markdown]
# # Analyze Confidence Scores

# %%
import json
import re

def compare_ditto_results(jsonl_path, txt_path):
    """
    Compares Ditto JSONL predictions with the actual text labels line-by-line.
    
    Returns:
        List of tuples: (line_number, predicted_class, actual_class, match_confidence)
    """
    comparison_results = []
    
    # Matches the final integer at the very end of the line
    actual_label_pattern = re.compile(r'(\d+)\s*$')

    with open(jsonl_path, 'r', encoding='utf-8') as f_pred, \
         open(txt_path, 'r', encoding='utf-8') as f_actual:
        
        for line_num, (line_pred, line_actual) in enumerate(zip(f_pred, f_actual), 1):
            # 1. Parse JSONL predictions
            data_pred = json.loads(line_pred.strip())
            predicted_class = data_pred.get('match')
            match_confidence = data_pred.get('match_confidence')
            
            # 2. Extract actual class from the text file line
            match_actual = actual_label_pattern.search(line_actual)
            if match_actual:
                actual_class = int(match_actual.group(1))
            else:
                actual_class = None  # Fallback if a line lacks a trailing integer
            
            # 3. Store the structured tuple
            if actual_class != predicted_class:
                comparison_results.append((
                    line_num, 
                    predicted_class, 
                    actual_class, 
                    match_confidence
                ))
            
    return comparison_results

# --- Run the comparison ---
if __name__ == "__main__":
    # file1 = "../imdb_results/movie_3_conv_results.jsonl"
    file1 = "../imdb_results/movie_baseline.jsonl"
    file2 = "../data/imdb/high/baseA/movie/test.txt"
    
    results = compare_ditto_results(file1, file2)
    
    # Quick look at the output structure
    print(f"Processed {len(results)} lines successfully.\n")
    print("Sample output tuple format:")
    print("(line_number, predicted, actual, confidence)")
    print("-" * 45)
    for entry in results:  # Adjust to see more rows if needed
        print(entry)
# Out:
# Processed 272 lines successfully.
#
# Sample output tuple format:
# (line_number, predicted, actual, confidence)
# ---------------------------------------------
# (1, 0, 1, 0.9828286976095886)
# (23, 0, 1, 0.9996001296818824)
# (31, 0, 1, 0.6142670968131203)
# (41, 0, 1, 0.9578454938246853)
# (99, 0, 1, 0.9383448948405327)
# (112, 0, 1, 0.537248029223779)
# (129, 0, 1, 0.7882847016522941)
# (132, 0, 1, 0.9667643565708863)
# (137, 1, 0, 0.8853346553250896)
# (148, 1, 0, 0.999886528473064)
# (159, 0, 1, 0.9993563600975056)
# (180, 0, 1, 0.5473581787166928)
# (219, 1, 0, 0.8449333366636312)
# (241, 0, 1, 0.9992733726147423)
# (269, 0, 1, 0.7220402458621047)
# (279, 0, 1, 0.8776501030514563)
# (289, 1, 0, 0.7927557385852522)
# (292, 0, 1, 0.7851174772072825)
# (298, 1, 0, 0.9994903408171142)
# (300, 0, 1, 0.9917229876597711)
# (321, 0, 1, 0.8705739826394907)
# (336, 0, 1, 0.6151837117234623)
# (360, 0, 1, 0.9907463891310967)
# (387, 0, 1, 0.6660391095496345)
# (410, 0, 1, 0.8114356814682353)
# (415, 1, 0, 0.9237222185219485)
# (422, 0, 1, 0.9803062659179578)
# (440, 0, 1, 0.6804487000162969)
# (451, 0, 1, 0.9885858627191836)
# (467, 0, 1, 0.7095478941255323)
# (476, 0, 1, 0.9991398524867715)
# (491, 0, 1, 0.7283957676741118)
# (493, 1, 0, 0.9466205409617964)
# (514, 0, 1, 0.7308190136431559)
# (527, 1, 0, 0.6183946802780061)
# (529, 0, 1, 0.7320613196137741)
# (546, 0, 1, 0.6675803595943336)
# (558, 0, 1, 0.8937810864888948)
# (564, 0, 1, 0.689598963180214)
# (566, 0, 1, 0.9997449324838474)
# (570, 0, 1, 0.7761697350468517)
# (577, 0, 1, 0.6212537309060436)
# (588, 1, 0, 0.8865329135510809)
# (610, 0, 1, 0.8239019722779612)
# (621, 0, 1, 0.506091025140832)
# (639, 0, 1, 0.8703590548434805)
# (645, 0, 1, 0.5782347564743631)
# (655, 0, 1, 0.7016090756087694)
# (720, 0, 1, 0.9000423584026584)
# (721, 0, 1, 0.9577709776747616)
# (3234, 0, 1, 0.8255482125510987)
# (3242, 0, 1, 0.8328062410793974)
# (3243, 1, 0, 0.9995040202031538)
# (3252, 0, 1, 0.5486773541373325)
# (3292, 0, 1, 0.7383515525398674)
# (3309, 0, 1, 0.6742197275531906)
# (3314, 0, 1, 0.7606661282084646)
# (3327, 0, 1, 0.9996364658993767)
# (3347, 0, 1, 0.5804163180497607)
# (3351, 1, 0, 0.6521100002620448)
# (3354, 0, 1, 0.8988229982013364)
# (3357, 0, 1, 0.6787934053602216)
# (3363, 0, 1, 0.6495156191388932)
# (3420, 0, 1, 0.6649107036543916)

# %%
import json
import re
import statistics

def analyze_model_improvements(file1_path, file2_path, file3_path):
    actual_label_pattern = re.compile(r'(\d+)\s*$')
    
    dataset = []
    
    with open(file1_path, 'r', encoding='utf-8') as f_base, \
         open(file2_path, 'r', encoding='utf-8') as f_actual, \
         open(file3_path, 'r', encoding='utf-8') as f_new:
        
        for line_base, line_actual, line_new in zip(f_base, f_actual, f_new):
            data_base = json.loads(line_base.strip())
            data_new = json.loads(line_new.strip())
            
            base_pred = data_base.get('match')
            base_conf = data_base.get('match_confidence')
            new_pred = data_new.get('match')
            
            match_actual = actual_label_pattern.search(line_actual)
            actual_class = int(match_actual.group(1)) if match_actual else None
            
            if actual_class is not None and base_conf is not None:
                dataset.append({
                    'base_conf': base_conf,
                    'base_correct': (base_pred == actual_class),
                    'new_correct': (new_pred == actual_class)
                })

    total_records = len(dataset)
    if total_records == 0:
        print("No valid data found to analyze.")
        return

    thresholds = [0.4, 0.5, 0.70, 0.80, 0.85, 0.90, 0.95, 0.97, 0.99, 0.995]
    
    print(f"{total_records} Total Pairs")
    print(f"{'Baseline Threshold':<20} | {'Remaining Errors'}")
    print("-" * 75)
    
    for t in thresholds:
        # Traffic that stays with baseline because confidence >= t
        baseline_traffic = [row for row in dataset if row['base_conf'] >= t]
        
        if not baseline_traffic:
            continue
            
        cost_saved_pct = (len(baseline_traffic) / total_records) * 100
        correct_count = sum(1 for row in baseline_traffic if row['base_correct'])
        baseline_accuracy = (correct_count / len(baseline_traffic)) * 100
        errors_passed = len(baseline_traffic) - correct_count
        
        # print(f"Confidence >= {t:<7.3f} | {cost_saved_pct:<13.1f}% | {baseline_accuracy:<18.2f}% | {errors_passed:<14}")
        print(f"Confidence >= {t:<7.3f} | {errors_passed:<14}")


file1 = "../imdb_results/movie_baseline.jsonl"
file2 = "../data/imdb/high/baseA/movie/test.txt"
file3 = "../imdb_results/movie_3_conv_results.jsonl"

analyze_model_improvements(file1, file2, file3)
# Out:
# 3444 Total Pairs
# Baseline Threshold   | Remaining Errors
# ---------------------------------------------------------------------------
# Confidence >= 0.400   | 272
# Confidence >= 0.500   | 272
# Confidence >= 0.700   | 172
# Confidence >= 0.800   | 130
# Confidence >= 0.850   | 118
# Confidence >= 0.900   | 97
# Confidence >= 0.950   | 77
# Confidence >= 0.970   | 63
# Confidence >= 0.990   | 53
# Confidence >= 0.995   | 34
