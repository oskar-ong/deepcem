# %%
import sqlite3

import pandas as pd
def run_sql_query(query: str)-> pd.DataFrame:
    conn = sqlite3.connect('../cem_results.db')
    try:
    
        # Execute and load into DataFrame
        df = pd.read_sql_query(query, conn)

    finally:
        conn.close()
    return df

# %%
def query_metrics(job_id):
    query = f"""SELECT 
        r.dataset,
        m.entity,
        m.metric_type,
        AVG(m.f1_score) AS mean_f1,
        SQRT((SUM(m.f1_score * m.f1_score) - (SUM(m.f1_score) * SUM(m.f1_score) / COUNT(m.f1_score))) / (COUNT(m.f1_score) - 1)) AS std_f1,
        COUNT(r.seed) AS num_seeds,
        r.train_size,
        r.pollution,
        r.batch_size,
        r.max_len,
        r.learning_rate,
        r.epochs,
        r.lm,
        r.neg_ratio
    FROM runs r
    JOIN metrics m ON r.run_id = m.run_id
    WHERE m.is_final = 1  AND m.run_id LIKE '{job_id}_%'
    GROUP BY 
        r.dataset, 
        r.train_size, 
        r.pollution, 
        r.batch_size, 
        r.max_len, 
        r.learning_rate, 
        r.epochs, 
        r.lm, 
        r.neg_ratio,
        m.entity, 
        m.metric_type
    ORDER BY r.dataset, m.entity, m.metric_type;"""

    df =  run_sql_query(query)
    df.drop(columns=["batch_size", "max_len", "learning_rate", "lm", "neg_ratio"], inplace=True)
    return df

# %%
def query_metrics_individual(job_id):
    query = f"""SELECT 
        r.dataset,
        m.entity,
        m.metric_type,
        m.f1_score, 
        r.seed,
        r.train_size,
        r.pollution,
        r.batch_size,
        r.max_len,
        r.learning_rate,
        r.epochs,
        r.lm,
        r.neg_ratio
    FROM runs r
    JOIN metrics m ON r.run_id = m.run_id
    WHERE m.is_final = 1  AND m.run_id LIKE '{job_id}_%'
    ORDER BY r.dataset, m.entity, m.metric_type;"""
    
    df =  run_sql_query(query)
    df.drop(columns=["batch_size", "max_len", "learning_rate", "lm", "neg_ratio"], inplace=True)
    return df

# %%
def query_prelimary(job_id):
    query = f"""SELECT 
        r.dataset,
        m.entity,
        m.metric_type,
        AVG(m.f1_score) AS mean_f1,
        SQRT((SUM(m.f1_score * m.f1_score) - (SUM(m.f1_score) * SUM(m.f1_score) / COUNT(m.f1_score))) / (COUNT(m.f1_score) - 1)) AS std_f1,
        COUNT(r.seed) AS num_seeds,
        r.train_size,
        r.pollution,
        r.batch_size,
        r.max_len,
        r.learning_rate,
        r.epochs,
        r.lm,
        r.neg_ratio
    FROM runs r
    JOIN metrics m ON r.run_id = m.run_id
    WHERE m.metric_type IN ('phase1', 'phase2', 'baseline') AND m.run_id LIKE '{job_id}_%'
    GROUP BY 
        r.dataset, 
        r.train_size, 
        r.pollution, 
        r.batch_size, 
        r.max_len, 
        r.learning_rate, 
        r.epochs, 
        r.lm, 
        r.neg_ratio,
        m.entity, 
        m.metric_type
    ORDER BY r.dataset, m.entity, m.metric_type;"""

    df =  run_sql_query(query)
    df.drop(columns=["batch_size", "max_len", "learning_rate", "lm", "neg_ratio"], inplace=True)

    # 1. Define the logical order
    pollution_order = ['source', 'low', 'medium', 'high']

    # 2. Apply the categorical type to the column
    df['pollution'] = pd.Categorical(
        df['pollution'], 
        categories=pollution_order, 
        ordered=True
    )

    # 3. Sort the DataFrame to reflect this order
    # This ensures that when you generate the table or plot, the rows are in order
    df = df.sort_values(by=['dataset', 'entity', 'pollution', 'metric_type'])
    return df

# %%
def generate_comparison_latex(df, test_metric='test', dataset_name='music'):
    # 1. Pivot the dataframe to get Baseline and Test side-by-side
    # We index by entity and pollution to keep them as rows

    # 1. Define the logical order
    pollution_order = ['source', 'low', 'medium', 'high']

    # 2. Apply the categorical type to the column
    df['pollution'] = pd.Categorical(
        df['pollution'], 
        categories=pollution_order, 
        ordered=True
    )

    # 3. Sort the DataFrame to reflect this order
    # This ensures that when you generate the table or plot, the rows are in order
    df = df.sort_values(by=['dataset', 'entity', 'pollution', 'metric_type'])


    pivot_df = df.pivot_table(
        index=['entity', 'pollution'], 
        columns='metric_type', 
        values=['mean_f1', 'std_f1']
    )

    # 2. Filter for only the levels we need (Baseline and the specific Test metric)
    # This ensures we don't have extra columns if the DF contains Phase 1, Phase 2, etc.
    try:
        baseline_mean = pivot_df[('mean_f1', 'baseline')]
        baseline_std = pivot_df[('std_f1', 'baseline')]
        test_mean = pivot_df[('mean_f1', test_metric)]
        test_std = pivot_df[('std_f1', test_metric)]
    except KeyError:
        return "Error: Metric types 'baseline' or '{}' not found in DataFrame.".format(test_metric)

    # 3. Build the LaTeX string
    latex_lines = [
        "\\begin{table}[h]",
        "\\centering",
        f"\\caption{{Main Experiment: Baseline vs. RETEM - Dataset {dataset_name}}}",
        "\\label{tab:main_exp_}}",
        "\\begin{tabular}{ll c cc c cc}",
        "\\toprule",
        " & & & \\multicolumn{2}{c}{\\textbf{Baseline}} & & \\multicolumn{2}{c}{\\textbf{RETEM}} \\\\",
        "\\cmidrule{4-5} \\cmidrule{7-8}",
        "\\textbf{Entity} & \\textbf{Pollution} & & \\textbf{Mean F1} & \\textbf{SD} & & \\textbf{Mean F1} & \\textbf{SD} \\\\",
        "\\midrule"
    ]

    # 4. Iterate through the pivoted rows and apply bolding logic
    for (entity, pollution) in pivot_df.index:
        m_b = baseline_mean.loc[(entity, pollution)]
        s_b = baseline_std.loc[(entity, pollution)]
        m_t = test_mean.loc[(entity, pollution)]
        s_t = test_std.loc[(entity, pollution)]

        # Bolding logic for the higher mean
        val_b = f"\\textbf{{{m_b:.4f}}}" if m_b > m_t else f"{m_b:.4f}"
        val_t = f"\\textbf{{{m_t:.4f}}}" if m_t > m_b else f"{m_t:.4f}"
        
        row = f"{entity} & {pollution} & & {val_b} & {s_b:.4f} & & {val_t} & {s_t:.4f} \\\\"
        latex_lines.append(row)

    latex_lines.append("\\bottomrule")
    latex_lines.append("\\end{tabular}")
    latex_lines.append("\\end{table}")

    return "\n".join(latex_lines)

# %%
def generate_comparison_latex_prelim(df, dataset_name='music'):
    # 1. Pivot the dataframe to get all metric types side-by-side
    pivot_df = df.pivot_table(
        index=['entity', 'pollution'], 
        columns='metric_type', 
        values=['mean_f1', 'std_f1']
    )

    # 2. Hardcode the metrics we want to extract
    target_phases = ['baseline', 'phase1', 'phase2']
    
    try:
        # Extract means and stds for all three phases
        m_b, s_b = pivot_df[('mean_f1', 'baseline')], pivot_df[('std_f1', 'baseline')]
        m_p1, s_p1 = pivot_df[('mean_f1', 'phase1')], pivot_df[('std_f1', 'phase1')]
        m_p2, s_p2 = pivot_df[('mean_f1', 'phase2')], pivot_df[('std_f1', 'phase2')]
    except KeyError as e:
        return f"Error: Required metric type {e} not found in DataFrame."

    # 3. Build the LaTeX string
    # tabular columns: Entity(l), Pollution(l), separator(c), B_Mean(c), B_SD(c), sep, P1_Mean, P1_SD, sep, P2_Mean, P2_SD
    latex_lines = [
        "\\begin{table}[h]",
        "\\centering",
        f"\\caption{{Baseline (Ditto pure) vs. Phase 1 (Empty Relational Scores) vs. Phase 2 (Relational Scores based on Ground-Truth) - Dataset {dataset_name}}}",
        "\\label{tab:prelim_exp_}",
        "\\begin{tabular}{ll c cc c cc c cc}",
        "\\toprule",
        " & & & \\multicolumn{2}{c}{\\textbf{Baseline}} & & \\multicolumn{2}{c}{\\textbf{Phase 1}} & & \\multicolumn{2}{c}{\\textbf{Phase 2}} \\\\",
        "\\cmidrule{4-5} \\cmidrule{7-8} \\cmidrule{10-11}",
        "\\textbf{Entity} & \\textbf{Pollution} & & \\textbf{Mean} & \\textbf{SD} & & \\textbf{Mean} & \\textbf{SD} & & \\textbf{Mean} & \\textbf{SD} \\\\",
        "\\midrule"
    ]

    # 4. Iterate through the rows and apply bolding logic across the three phases
    for (entity, pollution) in pivot_df.index:
        # Current row values
        vals_mean = {
            'b': m_b.loc[(entity, pollution)],
            'p1': m_p1.loc[(entity, pollution)],
            'p2': m_p2.loc[(entity, pollution)]
        }
        vals_std = {
            'b': s_b.loc[(entity, pollution)],
            'p1': s_p1.loc[(entity, pollution)],
            'p2': s_p2.loc[(entity, pollution)]
        }

        # Determine the maximum mean to apply bolding
        max_mean = max(vals_mean.values())

        def format_bold(val, target_max):
            return f"\\textbf{{{val:.4f}}}" if val == target_max else f"{val:.4f}"

        # Format strings for the row
        b_str = f"{format_bold(vals_mean['b'], max_mean)} & {vals_std['b']:.4f}"
        p1_str = f"{format_bold(vals_mean['p1'], max_mean)} & {vals_std['p1']:.4f}"
        p2_str = f"{format_bold(vals_mean['p2'], max_mean)} & {vals_std['p2']:.4f}"
        
        row = f"{entity} & {pollution} & & {b_str} & & {p1_str} & & {p2_str} \\\\"
        latex_lines.append(row)

    latex_lines.append("\\bottomrule")
    latex_lines.append("\\end{tabular}")
    latex_lines.append("\\end{table}")

    return "\n".join(latex_lines)

# %%
from pathlib import Path

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
def plot_degradation_line(df, dataset, rtype, lm="roberta"):
    # 1. Re-sort pollution for correct plotting
    pollution_order = ['source', 'low', 'medium', 'high']
    df['pollution'] = pd.Categorical(df['pollution'], categories=pollution_order, ordered=True)

# 1. Get unique entities from your dataframe
    entities = df['entity'].unique()

    # 2. Iterate through each entity to create individual plots
    for entity in entities:
        # Filter data for the specific entity
        entity_df = df[df['entity'] == entity].sort_values("pollution")
        
        # Initialize a new figure for each plot
        plt.figure(figsize=(8, 5))
        sns.set_theme(style="whitegrid")
        ax = plt.gca()
        
        # Define color palette to match previous plots
        palette = sns.color_palette("tab10", n_colors=len(df['metric_type'].unique()))
        metrics = entity_df['metric_type'].unique()

        # 3. Plot lines and SD bands for each metric type (Baseline, Phase 1, Phase 2, etc.)
        for i, metric in enumerate(metrics):
            subset = entity_df[entity_df['metric_type'] == metric]
            color = palette[i]
            
            # Plot the line
            sns.lineplot(
                data=subset, 
                x="pollution", 
                y="mean_f1", 
                marker="o", 
                label=metric, 
                color=color
            )
            # Edit here: Use Barplot instead
            # sns.barplot(
            #     data=subset, 
            #     x="pollution", 
            #     y="mean_f1", 
            #     # marker="o", 
            #     label=metric, 
            #     color=color
            # )
            
            # Plot the shaded SD band (Mean +/- SD)
            # Mapping categorical x-axis to numeric positions for fill_between
            x_coords = range(len(subset['pollution']))
            ax.fill_between(
                x_coords, 
                subset['mean_f1'] - subset['std_f1'], 
                subset['mean_f1'] + subset['std_f1'], 
                alpha=0.2, 
                color=color
            )

        # 4. Final formatting for the individual plot
        plt.ylim(0, 1) # Fix Y-axis from 0 to 1
        plt.title(f"Entity: {entity}")
        plt.xlabel("Pollution Level")
        plt.ylabel("Mean F1-Score")
        plt.legend(title="Metric Type", loc='lower left')
        plt.tight_layout()
        
        # 5. Save or Show the individual plot
        out_path = Path(
        f"../img/{lm}/{dataset}/{rtype}")
        Path(out_path).mkdir(parents=True, exist_ok=True)
        plt.savefig(f"../img/{lm}/{dataset}/{rtype}/f1_score_{entity}.png") 
        plt.show()

# %%
from pathlib import Path
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_degradation_barplot(df, dataset, rtype, lm="roberta"):
    # 1. Re-sort pollution for correct plotting
    pollution_order = ['source', 'low', 'medium', 'high']
    df['pollution'] = pd.Categorical(df['pollution'], categories=pollution_order, ordered=True)

    entities = df['entity'].unique()

    for entity in entities:
        entity_df = df[df['entity'] == entity].sort_values("pollution")
        
        plt.figure(figsize=(8, 5))
        sns.set_theme(style="whitegrid")

        ax = sns.barplot(
            data=entity_df, 
            x="pollution", 
            y="mean_f1", 
            hue="metric_type", 
            palette="tab10"
        )

        for container in ax.containers:

            ax.bar_label(
                container, 
                fmt='%.2f',      # Format to 2 decimal places
                padding=5,       # Space between bar/error bar and text
                fontsize=9,
                fontweight='bold'
            )

            metric_label = container.get_label()
            subset = entity_df[entity_df['metric_type'] == metric_label].sort_values("pollution")

            x_coords = [bar.get_x() + bar.get_width() / 2 for bar in container]

            y_errs = subset['std_f1'].values
            y_centers = subset['mean_f1'].values

            # Only plot if we have matching data (prevents size mismatch errors)
            if len(x_coords) == len(y_errs):
                ax.errorbar(
                    x=x_coords, 
                    y=y_centers, 
                    yerr=y_errs, 
                    fmt='none', 
                    c='black', 
                    capsize=3, 
                    elinewidth=1,
                    alpha=0.6
                )

        # 3. Final formatting
        plt.ylim(0, 1)
        plt.title(f"Entity: {entity}")
        plt.xlabel("Pollution Level")
        plt.ylabel("Mean F1-Score")
        
        # Move legend outside if it's crowded
        plt.legend(title="Metric Type", loc='upper left', bbox_to_anchor=(1, 1))
        plt.tight_layout()
        
        # 4. Save/Show
        out_path = Path(f"../img/{lm}/{dataset}/{rtype}")
        out_path.mkdir(parents=True, exist_ok=True)
        plt.savefig(out_path / f"f1_score_{entity}.png") 
        plt.show()

# %% [markdown]
# # Boxplot

# %%
# Boxplot

from pathlib import Path
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def plot_degradation_boxplot(df, dataset, rtype, lm="roberta"):
    pollution_order = ['source', 'low', 'medium', 'high']
    df['pollution'] = pd.Categorical(df['pollution'], categories=pollution_order, ordered=True)

    entities = df['entity'].unique()
    metric_types = df['metric_type'].unique()
    n_metrics = len(metric_types)

    for entity in entities:
        entity_df = df[df['entity'] == entity].sort_values("pollution")
        
        plt.figure(figsize=(10, 6))
        sns.set_theme(style="whitegrid")
        
        # 2. Plot the Boxplot
        # Note: 'y' should be your raw score column (e.g., 'f1_score')
        # If you only have 'mean_f1', this will just show a line.
        ax = sns.boxplot(
            data=entity_df, 
            x="pollution", 
            y="f1_score",  # Use the raw score column here
            hue="metric_type", 
            palette="tab10",
            showmeans=True,
            meanprops={
                "marker": "d",
                "markerfacecolor": "white",
                "markeredgecolor": "black",
                "markersize": 5
            },
            fliersize=4,      # Size of outlier points
            linewidth=1.5
        )

        for i, p_level in enumerate(pollution_order):
            for j, m_type in enumerate(metric_types):
                # Filter for this specific box
                subset = entity_df[(entity_df['pollution'] == p_level) & 
                                   (entity_df['metric_type'] == m_type)]
                
                if not subset.empty:
                    # Calculate mean
                    mean_val = subset['f1_score'].mean()
                    
                    # Calculate X-coordinate: 
                    # i is the category center (0, 1, 2...)
                    # The second part calculates the shift based on hue index
                    width = 0.8  # Default seaborn box width
                    x_pos = i + (j - (n_metrics - 1) / 2) * (width / n_metrics)
                    
                    # Add text slightly above the mean marker
                    ax.text(
                        x_pos, 
                        mean_val + 0.02, 
                        f'{mean_val:.2f}', 
                        ha='center', 
                        va='bottom', 
                        fontsize=9, 
                        fontweight='bold',
                        color='black'
                    )
        
        # Optional: Add a swarmplot on top to show individual data points
        # sns.stripplot(
        #     data=entity_df, 
        #     x="pollution", 
        #     y="f1_score", 
        #     hue="metric_type", 
        #     dodge=True, 
        #     alpha=0.3, 
        #     palette="dark:black"
        # )

        # 3. Final formatting
        plt.ylim(0.4, 1.05)
        plt.title(f"Score Distribution - Entity: {entity}", pad=20)
        plt.xlabel("Pollution Level")
        plt.ylabel("F1-Score")
        
        # Handle legend (preventing duplicates if using stripplot)
        handles, labels = ax.get_legend_handles_labels()
        # If you have 3 metric types, just take the first 3 handles
        unique_labels = len(df['metric_type'].unique())
        plt.legend(
            handles[:unique_labels], 
            labels[:unique_labels], 
            title="Metric Type", 
            loc='upper left', 
            bbox_to_anchor=(1, 1)
        )
        
        plt.tight_layout()
        
        # 4. Save/Show
        out_path = Path(f"../img/boxplots/{lm}/{dataset}/{rtype}")
        out_path.mkdir(parents=True, exist_ok=True)
        plt.savefig(out_path / f"boxplot_f1_{entity}.png") 
        plt.show()

# %% [markdown]
# # JOB ID: 9790002
#
# Dataset: IMDB
#
# Trainset size: Full
#
# Pollutions: source, low, medium, high
#
# lm: roberta

# %% [markdown]
# ## Main Results

# %%
df = query_metrics(9790002)

pollution_order = ['source', 'low', 'medium', 'high']
df['pollution'] = pd.Categorical(
    df['pollution'], 
    categories=pollution_order, 
    ordered=True
)

df = df.sort_values(by=['dataset', 'entity', 'pollution', 'metric_type'])

latex_code = generate_comparison_latex(df, test_metric='test')

print(latex_code)

plot_degradation(df, "imdb", "main", "roberta")
# Out:
# \begin{table}[h]
# \centering
# \caption{Main Experiment: Baseline vs. RETEM - Dataset music}
# \label{tab:main_exp_}}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{RETEM}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# movie & source & & 0.9984 & 0.0009 & & \textbf{0.9992} & 0.0008 \\
# movie & low & & 0.9627 & 0.0055 & & \textbf{0.9734} & 0.0058 \\
# movie & medium & & 0.9282 & 0.0078 & & \textbf{0.9480} & 0.0050 \\
# movie & high & & 0.8294 & 0.0056 & & \textbf{0.9158} & 0.0122 \\
# name & source & & \textbf{0.9994} & 0.0013 & & 0.9974 & 0.0021 \\
# name & low & & \textbf{0.9968} & 0.0005 & & 0.9952 & 0.0015 \\
# name & medium & & 0.9580 & 0.0042 & & \textbf{0.9820} & 0.0050 \\
# name & high & & 0.9188 & 0.0110 & & \textbf{0.9740} & 0.0099 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# ## IMDB Prelim

# %%
df = query_prelimary(9790002)

latex_code = df.to_latex(
    index=False, 
    caption="Summary of F1 Scores across Multiple Runs",
    label="tab:f1_results",
    float_format="%.4f"
)

print(latex_code)

plot_degradation(df, "imdb", "prelim")
# Out:
# \begin{table}
# \caption{Summary of F1 Scores across Multiple Runs}
# \label{tab:f1_results}
# \begin{tabular}{lllrrrrlr}
# \toprule
# dataset & entity & metric_type & mean_f1 & std_f1 & num_seeds & train_size & pollution & epochs \\
# \midrule
# imdb & movie & baseline & 0.9984 & 0.0009 & 5 & 1.0000 & source & 10 \\
# imdb & movie & phase1 & 0.9990 & 0.0007 & 5 & 1.0000 & source & 10 \\
# imdb & movie & phase2 & 0.9988 & 0.0016 & 5 & 1.0000 & source & 10 \\
# imdb & movie & baseline & 0.9627 & 0.0055 & 4 & 1.0000 & low & 10 \\
# imdb & movie & phase1 & 0.9702 & 0.0043 & 5 & 1.0000 & low & 10 \\
# imdb & movie & phase2 & 0.9730 & 0.0039 & 5 & 1.0000 & low & 10 \\
# imdb & movie & baseline & 0.9282 & 0.0078 & 5 & 1.0000 & medium & 10 \\
# imdb & movie & phase1 & 0.9243 & 0.0060 & 4 & 1.0000 & medium & 10 \\
# imdb & movie & phase2 & 0.9475 & 0.0047 & 4 & 1.0000 & medium & 10 \\
# imdb & movie & baseline & 0.8294 & 0.0056 & 5 & 1.0000 & high & 10 \\
# imdb & movie & phase1 & 0.8352 & 0.0052 & 5 & 1.0000 & high & 10 \\
# imdb & movie & phase2 & 0.9054 & 0.0050 & 5 & 1.0000 & high & 10 \\
# imdb & name & baseline & 0.9994 & 0.0013 & 5 & 1.0000 & source & 10 \\
# imdb & name & phase1 & 0.9980 & 0.0019 & 5 & 1.0000 & source & 10 \\
# imdb & name & phase2 & 0.9970 & 0.0023 & 5 & 1.0000 & source & 10 \\
# imdb & name & baseline & 0.9968 & 0.0005 & 4 & 1.0000 & low & 10 \\
# imdb & name & phase1 & 0.9946 & 0.0017 & 5 & 1.0000 & low & 10 \\
# imdb & name & phase2 & 0.9952 & 0.0024 & 5 & 1.0000 & low & 10 \\
# imdb & name & baseline & 0.9580 & 0.0042 & 5 & 1.0000 & medium & 10 \\
# imdb & name & phase1 & 0.9597 & 0.0048 & 4 & 1.0000 & medium & 10 \\
# imdb & name & phase2 & 0.9835 & 0.0019 & 4 & 1.0000 & medium & 10 \\
# imdb & name & baseline & 0.9188 & 0.0110 & 5 & 1.0000 & high & 10 \\
# imdb & name & phase1 & 0.9252 & 0.0056 & 5 & 1.0000 & high & 10 \\
# imdb & name & phase2 & 0.9818 & 0.0015 & 5 & 1.0000 & high & 10 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# # JOB ID: 9790092
#
# Dataset: music
#
# Trainset size: Full
#
# Pollutions: source, low, medium, high
#
# lm: roberta

# %% [markdown]
# ## Main

# %%
df = query_metrics(9790092)

# latex_code = df.to_latex(
#     index=False, 
#     caption="Summary of F1 Scores across Multiple Runs",
#     label="tab:f1_results",
#     float_format="%.4f"
# )

# 1. Define the logical order
pollution_order = ['source', 'low', 'medium', 'high']

# 2. Apply the categorical type to the column
df['pollution'] = pd.Categorical(
    df['pollution'], 
    categories=pollution_order, 
    ordered=True
)

# 3. Sort the DataFrame to reflect this order
# This ensures that when you generate the table or plot, the rows are in order
df = df.sort_values(by=['dataset', 'entity', 'pollution', 'metric_type'])

latex_code = generate_comparison_latex(df, test_metric='test')

print(latex_code)

plot_degradation(df, "music", "main")
# Out:
# \begin{table}[h]
# \centering
# \caption{Comparison of F1 Scores: Baseline vs. Test (test) - Dataset music}
# \label{tab:f1_comparison_auto}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{Test (Test)}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# area & source & & \textbf{0.9622} & 0.0174 & & 0.8640 & 0.2596 \\
# area & low & & 0.9266 & 0.0022 & & \textbf{0.9592} & 0.0145 \\
# area & medium & & 0.8918 & 0.0318 & & 0.8918 & 0.0184 \\
# area & high & & 0.4386 & 0.0098 & & \textbf{0.5886} & 0.1701 \\
# artist & source & & \textbf{0.9992} & 0.0018 & & 0.9962 & 0.0039 \\
# artist & low & & \textbf{1.0000} & 0.0000 & & 0.9926 & 0.0046 \\
# artist & medium & & \textbf{0.9976} & 0.0033 & & 0.9946 & 0.0049 \\
# artist & high & & \textbf{0.9980} & nan & & 0.9838 & 0.0083 \\
# artist_credit & source & & 0.9874 & 0.0031 & & \textbf{0.9950} & 0.0034 \\
# artist_credit & low & & \textbf{0.9946} & 0.0022 & & 0.9880 & 0.0049 \\
# artist_credit & medium & & 0.9692 & 0.0044 & & \textbf{0.9780} & 0.0037 \\
# artist_credit & high & & \textbf{0.9432} & 0.0018 & & 0.9290 & 0.0125 \\
# label & source & & \textbf{0.9868} & 0.0027 & & 0.9768 & 0.0070 \\
# label & low & & \textbf{0.9644} & 0.0077 & & 0.9558 & 0.0125 \\
# label & medium & & \textbf{0.9286} & 0.0022 & & 0.8048 & 0.2303 \\
# label & high & & \textbf{0.8674} & 0.0058 & & 0.8278 & 0.0132 \\
# medium & source & & \textbf{0.9734} & 0.0013 & & 0.9672 & 0.0081 \\
# medium & low & & \textbf{0.9550} & 0.0000 & & 0.9026 & 0.0376 \\
# medium & medium & & \textbf{0.8878} & 0.0148 & & 0.8278 & 0.0257 \\
# medium & high & & \textbf{0.8190} & 0.0157 & & 0.6782 & 0.0602 \\
# place & source & & 0.7386 & 0.1377 & & \textbf{0.9658} & 0.0178 \\
# place & low & & 0.8448 & 0.1189 & & \textbf{0.9610} & 0.0162 \\
# place & medium & & \textbf{0.9302} & 0.0044 & & 0.9060 & 0.0376 \\
# place & high & & \textbf{0.9082} & 0.0027 & & 0.7462 & 0.0663 \\
# recording & source & & \textbf{0.9980} & nan & & 0.9948 & 0.0083 \\
# recording & low & & \textbf{0.9904} & 0.0033 & & 0.9894 & 0.0035 \\
# recording & medium & & \textbf{0.9716} & 0.0022 & & 0.9554 & 0.0109 \\
# recording & high & & \textbf{0.9212} & 0.0018 & & 0.7908 & 0.2193 \\
# release & source & & \textbf{0.9914} & 0.0009 & & 0.9870 & 0.0057 \\
# release & low & & \textbf{0.9820} & nan & & 0.9592 & 0.0460 \\
# release & medium & & \textbf{0.9820} & nan & & 0.9332 & 0.0726 \\
# release & high & & \textbf{0.9382} & 0.0072 & & 0.8984 & 0.0314 \\
# release_group & source & & 0.9828 & 0.0072 & & \textbf{0.9864} & 0.0078 \\
# release_group & low & & 0.9420 & 0.0164 & & \textbf{0.9448} & 0.0072 \\
# release_group & medium & & \textbf{0.9040} & 0.0055 & & 0.8724 & 0.0164 \\
# release_group & high & & \textbf{0.7962} & 0.0116 & & 0.7716 & 0.0313 \\
# track & source & & \textbf{0.9990} & 0.0000 & & 0.9966 & 0.0017 \\
# track & low & & 0.9950 & 0.0000 & & \textbf{0.9978} & 0.0008 \\
# track & medium & & \textbf{0.9902} & 0.0016 & & 0.9888 & 0.0037 \\
# track & high & & \textbf{0.9842} & 0.0004 & & 0.9812 & 0.0036 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# ### Investigate high SD

# %%
# Define your threshold
threshold = 0.05

# Filter the aggregated dataframe to find problematic configurations
high_sd_df = df[df['std_f1'] > threshold].copy()

print(f"Found {len(high_sd_df)} rows with Standard Deviation > {threshold}")
display(high_sd_df)
# Out:
# Found 9 rows with Standard Deviation > 0.05
#    dataset     entity metric_type  mean_f1    std_f1  num_seeds  train_size  \
# 7    music       area        test   0.8640  0.259577          5         1.0
# 4    music       area        test   0.5886  0.170110          5         1.0
# 30   music      label        test   0.8048  0.230303          5         1.0
# 36   music     medium        test   0.6782  0.060218          5         1.0
# 43   music      place    baseline   0.7386  0.137742          5         1.0
# 41   music      place    baseline   0.8448  0.118856          5         1.0
# 44   music      place        test   0.7462  0.066285          5         1.0
# 52   music  recording        test   0.7908  0.219271          5         1.0
# 62   music    release        test   0.9332  0.072565          5         1.0
#
#    pollution  epochs
# 7     source      10
# 4       high      10
# 30    medium      10
# 36      high      10
# 43    source      10
# 41       low      10
# 44      high      10
# 52      high      10
# 62    medium      10

# %%
# Get all run_ids for high sd rows
def investigate_outliers(outlier_row, job_id):
    """
    Fetches raw scores for all seeds associated with a high-SD configuration.
    """
    # Extract row identifiers
    dataset = outlier_row['dataset']
    entity = outlier_row['entity']
    m_type = outlier_row['metric_type']
    pollution = outlier_row['pollution']

    # Query individual runs
    query = f"""
    SELECT 
        m.run_id,
        m.entity,
        r.seed,
        m.f1_score,
        m.precision,
        m.recall,
        m.iteration
    FROM runs r
    JOIN metrics m ON r.run_id = m.run_id
    WHERE r.dataset = '{dataset}'
      AND m.entity = '{entity}'
      AND m.metric_type = '{m_type}'
      AND r.pollution = '{pollution}'
      AND m.run_id LIKE '{job_id}_%'

    ORDER BY m.f1_score ASC;
    """
    
    raw_metrics_df = run_sql_query(query)
    return raw_metrics_df

# Example: Investigate the first row in your high_sd_df
outlier_details = investigate_outliers(high_sd_df.iloc[1], 9790092)
display(outlier_details)
# Out:
#        run_id entity  seed  f1_score  precision  recall  iteration
# 0  9790092_15   area     1     0.400      0.250   1.000          0
# 1  9790092_15   area     1     0.400      0.250   1.000          1
# 2  9790092_18   area     4     0.405      0.533   0.327          0
# 3  9790092_18   area     4     0.405      0.533   0.327          1
# 4  9790092_19   area     5     0.699      0.853   0.592          0
# 5  9790092_19   area     5     0.699      0.853   0.592          1
# 6  9790092_17   area     3     0.717      0.767   0.673          0
# 7  9790092_17   area     3     0.717      0.767   0.673          1
# 8  9790092_16   area     2     0.722      0.661   0.796          0
# 9  9790092_16   area     2     0.722      0.661   0.796          1

# %% [markdown]
# ## Prelim

# %%
# Signal validity

df = query_prelimary(9790092)

latex_code = df.to_latex(
    index=False, 
    caption="Summary of F1 Scores across Multiple Runs",
    label="tab:f1_results",
    float_format="%.4f"
)

latex_code = generate_comparison_latex_prelim(df, "music")

print(latex_code)

plot_degradation(df, "music", "prelim")
# Out:
# \begin{table}[h]
# \centering
# \caption{Comparison of F1 Scores: Baseline vs. Phase 1 vs. Phase 2 - Dataset music}
# \label{tab:f1_comparison_phases}
# \begin{tabular}{ll c cc c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{Phase 1}} & & \multicolumn{2}{c}{\textbf{Phase 2}} \\
# \cmidrule{4-5} \cmidrule{7-8} \cmidrule{10-11}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} \\
# \midrule
# area & source & & \textbf{0.9622} & 0.0174 & & 0.8396 & 0.2474 & & 0.8558 & 0.2551 \\
# area & low & & 0.9266 & 0.0022 & & 0.8272 & 0.2409 & & \textbf{0.9530} & 0.0117 \\
# area & medium & & \textbf{0.8918} & 0.0318 & & 0.8656 & 0.0252 & & 0.8910 & 0.0143 \\
# area & high & & 0.4386 & 0.0098 & & 0.4336 & 0.0740 & & \textbf{0.6358} & 0.1885 \\
# artist & source & & 0.9992 & 0.0018 & & 0.9976 & 0.0022 & & \textbf{1.0000} & 0.0000 \\
# artist & low & & \textbf{1.0000} & 0.0000 & & 0.9992 & 0.0018 & & 0.9996 & 0.0009 \\
# artist & medium & & 0.9976 & 0.0033 & & \textbf{0.9992} & 0.0018 & & 0.9984 & 0.0026 \\
# artist & high & & \textbf{0.9980} & nan & & 0.9950 & 0.0035 & & 0.9942 & 0.0020 \\
# artist_credit & source & & 0.9874 & 0.0031 & & 0.9914 & 0.0062 & & \textbf{0.9944} & 0.0046 \\
# artist_credit & low & & \textbf{0.9946} & 0.0022 & & 0.9856 & 0.0089 & & 0.9874 & 0.0046 \\
# artist_credit & medium & & 0.9692 & 0.0044 & & 0.9812 & 0.0025 & & \textbf{0.9846} & 0.0104 \\
# artist_credit & high & & 0.9432 & 0.0018 & & 0.9278 & 0.0166 & & \textbf{0.9804} & 0.0058 \\
# label & source & & \textbf{0.9868} & 0.0027 & & 0.9818 & 0.0046 & & 0.9794 & 0.0043 \\
# label & low & & \textbf{0.9644} & 0.0077 & & 0.9636 & 0.0069 & & 0.9620 & 0.0127 \\
# label & medium & & \textbf{0.9286} & 0.0022 & & 0.8280 & 0.2393 & & 0.8226 & 0.2369 \\
# label & high & & 0.8674 & 0.0058 & & 0.7646 & 0.2054 & & \textbf{0.8748} & 0.0081 \\
# medium & source & & 0.9734 & 0.0013 & & 0.9722 & 0.0052 & & \textbf{1.0000} & 0.0000 \\
# medium & low & & 0.9550 & 0.0000 & & 0.9342 & 0.0196 & & \textbf{0.9718} & 0.0485 \\
# medium & medium & & 0.8878 & 0.0148 & & 0.8970 & 0.0127 & & \textbf{0.9932} & 0.0038 \\
# medium & high & & 0.8190 & 0.0157 & & 0.8158 & 0.0289 & & \textbf{0.9738} & 0.0067 \\
# place & source & & 0.7386 & 0.1377 & & \textbf{0.9850} & 0.0071 & & 0.9718 & 0.0085 \\
# place & low & & 0.8448 & 0.1189 & & 0.9684 & 0.0239 & & \textbf{0.9718} & 0.0086 \\
# place & medium & & 0.9302 & 0.0044 & & 0.9440 & 0.0199 & & \textbf{0.9462} & 0.0152 \\
# place & high & & 0.9082 & 0.0027 & & 0.8974 & 0.0369 & & \textbf{0.9106} & 0.0279 \\
# recording & source & & \textbf{0.9980} & nan & & 0.9978 & 0.0019 & & 0.9962 & 0.0047 \\
# recording & low & & 0.9904 & 0.0033 & & 0.9884 & 0.0069 & & \textbf{0.9918} & 0.0025 \\
# recording & medium & & 0.9716 & 0.0022 & & 0.9724 & 0.0046 & & \textbf{0.9758} & 0.0058 \\
# recording & high & & \textbf{0.9212} & 0.0018 & & 0.8196 & 0.2347 & & 0.8300 & 0.2405 \\
# release & source & & 0.9914 & 0.0009 & & 0.9944 & 0.0023 & & \textbf{0.9954} & 0.0005 \\
# release & low & & 0.9820 & nan & & 0.9846 & 0.0069 & & \textbf{0.9920} & 0.0055 \\
# release & medium & & 0.9820 & nan & & 0.9824 & 0.0033 & & \textbf{0.9840} & 0.0068 \\
# release & high & & 0.9382 & 0.0072 & & 0.9514 & 0.0059 & & \textbf{0.9912} & 0.0078 \\
# release_group & source & & 0.9828 & 0.0072 & & 0.9816 & 0.0055 & & \textbf{0.9838} & 0.0086 \\
# release_group & low & & 0.9420 & 0.0164 & & 0.9444 & 0.0123 & & \textbf{0.9802} & 0.0084 \\
# release_group & medium & & 0.9040 & 0.0055 & & 0.8010 & 0.2242 & & \textbf{0.9468} & 0.0024 \\
# release_group & high & & 0.7962 & 0.0116 & & 0.8124 & 0.0077 & & \textbf{0.9044} & 0.0176 \\
# track & source & & \textbf{0.9990} & 0.0000 & & 0.9974 & 0.0013 & & 0.9962 & 0.0019 \\
# track & low & & 0.9950 & 0.0000 & & 0.9968 & 0.0013 & & \textbf{0.9974} & 0.0015 \\
# track & medium & & 0.9902 & 0.0016 & & 0.9872 & 0.0050 & & \textbf{0.9922} & 0.0030 \\
# track & high & & 0.9842 & 0.0004 & & 0.9804 & 0.0031 & & \textbf{0.9908} & 0.0060 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# # JOB ID: 9790670
#
# Dataset: IMDB
#
# Trainset size: Full
#
# Pollutions: source, low, medium, high
#
# lm: distillbert

# %%
imdb_distillbert = 9790670
df = query_prelimary(imdb_distillbert)

# 1. Define the logical order
pollution_order = ['source', 'low', 'medium', 'high']

# 2. Apply the categorical type to the column
df['pollution'] = pd.Categorical(
    df['pollution'], 
    categories=pollution_order, 
    ordered=True
)

# 3. Sort the DataFrame to reflect this order
# This ensures that when you generate the table or plot, the rows are in order
df = df.sort_values(by=['dataset', 'entity', 'pollution', 'metric_type'])

latex_code = generate_comparison_latex(df, test_metric='test')

print(latex_code)

plot_degradation(df, "imdb", "prelim", "distillbert")
# Out:
# Error: Metric types 'baseline' or 'test' not found in DataFrame.

# %%
df = query_metrics(imdb_distillbert)

# 1. Define the logical order
pollution_order = ['source', 'low', 'medium', 'high']

# 2. Apply the categorical type to the column
df['pollution'] = pd.Categorical(
    df['pollution'], 
    categories=pollution_order, 
    ordered=True
)

# 3. Sort the DataFrame to reflect this order
# This ensures that when you generate the table or plot, the rows are in order
df = df.sort_values(by=['dataset', 'entity', 'pollution', 'metric_type'])

latex_code = generate_comparison_latex(df, test_metric='test')

print(latex_code)

plot_degradation(df, "imdb", "main", "distillbert")
# Out:
# \begin{table}[h]
# \centering
# \caption{Comparison of F1 Scores: Baseline vs. Test (test) - Dataset music}
# \label{tab:f1_comparison_auto}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{Test (Test)}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# movie & source & & 0.9972 & 0.0004 & & \textbf{0.9974} & 0.0005 \\
# movie & low & & 0.9704 & 0.0015 & & \textbf{0.9716} & 0.0052 \\
# movie & medium & & 0.9144 & 0.0033 & & \textbf{0.9434} & 0.0111 \\
# movie & high & & 0.7976 & 0.0009 & & \textbf{0.9014} & 0.0090 \\
# name & source & & 0.9970 & nan & & \textbf{0.9988} & 0.0011 \\
# name & low & & 0.9904 & 0.0019 & & \textbf{0.9954} & 0.0029 \\
# name & medium & & 0.9512 & 0.0020 & & \textbf{0.9688} & 0.0108 \\
# name & high & & 0.8826 & 0.0043 & & \textbf{0.9292} & 0.0157 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# # JOB ID: 9790709
#
# Dataset: music
#
# Trainset size: Full
#
# Pollutions: source, low, medium, high
#
# lm: distillbert

# %%
music_distillbert = 9790709
df = query_prelimary(music_distillbert)

# 1. Define the logical order
pollution_order = ['source', 'low', 'medium', 'high']

# 2. Apply the categorical type to the column
df['pollution'] = pd.Categorical(
    df['pollution'], 
    categories=pollution_order, 
    ordered=True
)

# 3. Sort the DataFrame to reflect this order
# This ensures that when you generate the table or plot, the rows are in order
df = df.sort_values(by=['dataset', 'entity', 'pollution', 'metric_type'])

latex_code = generate_comparison_latex_prelim(df)

print(latex_code)

plot_degradation(df, "imdb", "prelim", "distillbert")
# Out:
# \begin{table}[h]
# \centering
# \caption{Comparison of F1 Scores: Baseline vs. Phase 1 vs. Phase 2 - Dataset music}
# \label{tab:f1_comparison_phases}
# \begin{tabular}{ll c cc c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{Phase 1}} & & \multicolumn{2}{c}{\textbf{Phase 2}} \\
# \cmidrule{4-5} \cmidrule{7-8} \cmidrule{10-11}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} \\
# \midrule
# area & source & & \textbf{0.8436} & 0.0434 & & 0.7850 & 0.0342 & & 0.8348 & 0.0194 \\
# area & low & & 0.7488 & 0.0427 & & 0.7034 & 0.0477 & & \textbf{0.7756} & 0.0342 \\
# area & medium & & 0.6144 & 0.0252 & & 0.5602 & 0.0344 & & \textbf{0.7350} & 0.0492 \\
# area & high & & 0.4384 & 0.0322 & & 0.4308 & 0.0623 & & \textbf{0.5952} & 0.0552 \\
# artist & source & & 0.9922 & 0.0040 & & \textbf{0.9968} & 0.0041 & & 0.9964 & 0.0043 \\
# artist & low & & 0.9956 & 0.0022 & & 0.9964 & 0.0030 & & \textbf{0.9968} & 0.0018 \\
# artist & medium & & 0.9944 & 0.0022 & & 0.9932 & 0.0050 & & \textbf{0.9980} & 0.0014 \\
# artist & high & & 0.9882 & 0.0018 & & 0.9890 & 0.0051 & & \textbf{0.9932} & 0.0023 \\
# artist_credit & source & & \textbf{0.9942} & 0.0018 & & 0.9898 & 0.0061 & & 0.9904 & 0.0075 \\
# artist_credit & low & & 0.9868 & 0.0011 & & 0.9862 & 0.0036 & & \textbf{0.9892} & 0.0055 \\
# artist_credit & medium & & 0.9642 & 0.0071 & & 0.9712 & 0.0019 & & \textbf{0.9880} & 0.0058 \\
# artist_credit & high & & 0.9274 & 0.0036 & & 0.9134 & 0.0044 & & \textbf{0.9754} & 0.0083 \\
# label & source & & \textbf{0.9700} & 0.0000 & & 0.9612 & 0.0074 & & 0.9614 & 0.0059 \\
# label & low & & \textbf{0.9382} & 0.0011 & & 0.9304 & 0.0087 & & 0.9254 & 0.0108 \\
# label & medium & & 0.8742 & 0.0044 & & 0.8928 & 0.0129 & & \textbf{0.8946} & 0.0088 \\
# label & high & & 0.8084 & 0.0080 & & 0.7982 & 0.0206 & & \textbf{0.8110} & 0.0196 \\
# medium & source & & 0.9740 & 0.0000 & & 0.9678 & 0.0065 & & \textbf{0.9940} & 0.0134 \\
# medium & low & & 0.9326 & 0.0077 & & 0.9454 & 0.0078 & & \textbf{0.9864} & 0.0088 \\
# medium & medium & & 0.8858 & 0.0038 & & 0.8924 & 0.0099 & & \textbf{0.9938} & 0.0043 \\
# medium & high & & 0.7964 & 0.0277 & & 0.7838 & 0.0177 & & \textbf{0.9704} & 0.0085 \\
# place & source & & 0.9420 & 0.0022 & & 0.9640 & 0.0109 & & \textbf{0.9730} & 0.0045 \\
# place & low & & 0.9576 & 0.0159 & & 0.9584 & 0.0118 & & \textbf{0.9616} & 0.0027 \\
# place & medium & & \textbf{0.9392} & 0.0011 & & 0.9298 & 0.0068 & & 0.9306 & 0.0157 \\
# place & high & & 0.8648 & 0.0004 & & 0.8768 & 0.0119 & & \textbf{0.8854} & 0.0084 \\
# recording & source & & 0.9946 & 0.0013 & & 0.9966 & 0.0018 & & \textbf{0.9970} & 0.0027 \\
# recording & low & & 0.9804 & 0.0049 & & 0.9808 & 0.0075 & & \textbf{0.9852} & 0.0039 \\
# recording & medium & & 0.9678 & 0.0038 & & 0.9676 & 0.0015 & & \textbf{0.9726} & 0.0036 \\
# recording & high & & 0.9136 & 0.0103 & & 0.9148 & 0.0024 & & \textbf{0.9330} & 0.0131 \\
# release & source & & 0.9898 & 0.0018 & & 0.9900 & 0.0066 & & \textbf{0.9954} & 0.0018 \\
# release & low & & 0.9824 & 0.0022 & & 0.9796 & 0.0005 & & \textbf{0.9914} & 0.0086 \\
# release & medium & & 0.9748 & 0.0044 & & 0.9772 & 0.0028 & & \textbf{0.9978} & 0.0018 \\
# release & high & & 0.9416 & 0.0031 & & 0.9432 & 0.0045 & & \textbf{0.9958} & 0.0029 \\
# release_group & source & & 0.9606 & 0.0036 & & 0.9642 & 0.0061 & & \textbf{0.9798} & 0.0133 \\
# release_group & low & & 0.9342 & 0.0066 & & 0.9298 & 0.0137 & & \textbf{0.9606} & 0.0180 \\
# release_group & medium & & 0.8602 & 0.0016 & & 0.8700 & 0.0115 & & \textbf{0.9286} & 0.0075 \\
# release_group & high & & 0.7504 & 0.0076 & & 0.7472 & 0.0091 & & \textbf{0.8848} & 0.0169 \\
# track & source & & \textbf{0.9980} & nan & & 0.9974 & 0.0009 & & 0.9966 & 0.0022 \\
# track & low & & 0.9966 & 0.0005 & & \textbf{0.9970} & 0.0007 & & \textbf{0.9970} & 0.0010 \\
# track & medium & & 0.9870 & 0.0000 & & 0.9874 & 0.0024 & & \textbf{0.9880} & 0.0059 \\
# track & high & & 0.9692 & 0.0027 & & 0.9748 & 0.0045 & & \textbf{0.9818} & 0.0070 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
df = query_metrics(music_distillbert)

# 1. Define the logical order
pollution_order = ['source', 'low', 'medium', 'high']

# 2. Apply the categorical type to the column
df['pollution'] = pd.Categorical(
    df['pollution'], 
    categories=pollution_order, 
    ordered=True
)

# 3. Sort the DataFrame to reflect this order
# This ensures that when you generate the table or plot, the rows are in order
df = df.sort_values(by=['dataset', 'entity', 'pollution', 'metric_type'])

latex_code = generate_comparison_latex(df, test_metric='test')

print(latex_code)

plot_degradation(df, "imdb", "main", "distillbert")
# Out:
# \begin{table}[h]
# \centering
# \caption{Comparison of F1 Scores: Baseline vs. Test (test) - Dataset music}
# \label{tab:f1_comparison_auto}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{Test (Test)}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# area & source & & \textbf{0.8436} & 0.0434 & & 0.8176 & 0.0142 \\
# area & low & & \textbf{0.7488} & 0.0427 & & 0.7432 & 0.0248 \\
# area & medium & & 0.6144 & 0.0252 & & \textbf{0.6974} & 0.0316 \\
# area & high & & 0.4384 & 0.0322 & & \textbf{0.4984} & 0.0250 \\
# artist & source & & \textbf{0.9922} & 0.0040 & & 0.9384 & 0.0328 \\
# artist & low & & \textbf{0.9956} & 0.0022 & & 0.9242 & 0.0512 \\
# artist & medium & & \textbf{0.9944} & 0.0022 & & 0.9292 & 0.0345 \\
# artist & high & & \textbf{0.9882} & 0.0018 & & 0.8234 & 0.1132 \\
# artist_credit & source & & \textbf{0.9942} & 0.0018 & & 0.9900 & 0.0072 \\
# artist_credit & low & & \textbf{0.9868} & 0.0011 & & 0.9832 & 0.0089 \\
# artist_credit & medium & & \textbf{0.9642} & 0.0071 & & 0.9556 & 0.0221 \\
# artist_credit & high & & \textbf{0.9274} & 0.0036 & & 0.8644 & 0.0567 \\
# label & source & & \textbf{0.9700} & 0.0000 & & 0.9546 & 0.0086 \\
# label & low & & \textbf{0.9382} & 0.0011 & & 0.8996 & 0.0360 \\
# label & medium & & \textbf{0.8742} & 0.0044 & & 0.8676 & 0.0103 \\
# label & high & & \textbf{0.8084} & 0.0080 & & 0.7270 & 0.0161 \\
# medium & source & & \textbf{0.9740} & 0.0000 & & 0.9562 & 0.0326 \\
# medium & low & & \textbf{0.9326} & 0.0077 & & 0.8794 & 0.0186 \\
# medium & medium & & \textbf{0.8858} & 0.0038 & & 0.8178 & 0.0387 \\
# medium & high & & \textbf{0.7964} & 0.0277 & & 0.6226 & 0.0580 \\
# place & source & & \textbf{0.9420} & 0.0022 & & 0.9356 & 0.0287 \\
# place & low & & \textbf{0.9576} & 0.0159 & & 0.9170 & 0.0114 \\
# place & medium & & \textbf{0.9392} & 0.0011 & & 0.8600 & 0.0534 \\
# place & high & & \textbf{0.8648} & 0.0004 & & 0.7560 & 0.0910 \\
# recording & source & & 0.9946 & 0.0013 & & \textbf{0.9958} & 0.0031 \\
# recording & low & & 0.9804 & 0.0049 & & 0.9804 & 0.0038 \\
# recording & medium & & \textbf{0.9678} & 0.0038 & & 0.9590 & 0.0053 \\
# recording & high & & \textbf{0.9136} & 0.0103 & & 0.8884 & 0.0213 \\
# release & source & & \textbf{0.9898} & 0.0018 & & 0.9680 & 0.0266 \\
# release & low & & \textbf{0.9824} & 0.0022 & & 0.9142 & 0.0970 \\
# release & medium & & \textbf{0.9748} & 0.0044 & & 0.8634 & 0.0954 \\
# release & high & & \textbf{0.9416} & 0.0031 & & 0.7560 & 0.0855 \\
# release_group & source & & \textbf{0.9606} & 0.0036 & & 0.9584 & 0.0074 \\
# release_group & low & & \textbf{0.9342} & 0.0066 & & 0.9214 & 0.0146 \\
# release_group & medium & & \textbf{0.8602} & 0.0016 & & 0.8560 & 0.0112 \\
# release_group & high & & \textbf{0.7504} & 0.0076 & & 0.7244 & 0.0412 \\
# track & source & & \textbf{0.9980} & nan & & 0.9964 & 0.0023 \\
# track & low & & 0.9966 & 0.0005 & & \textbf{0.9972} & 0.0004 \\
# track & medium & & \textbf{0.9870} & 0.0000 & & 0.9854 & 0.0029 \\
# track & high & & 0.9692 & 0.0027 & & \textbf{0.9720} & 0.0058 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# # 9795639
#
# - Changed Learning rate for refinetune to 1e-5
# - changed relational scores to "" for iteration 0
# - changed relational scores to "" if neighborhood is empty
# - increased max sequence length to 512

# %% [markdown]
# ## Prelim

# %%
# music_distillbert2 = 9791153
music_distillbert2 = 9795639
df = query_prelimary(music_distillbert2)

pollution_order = ['source', 'low', 'medium', 'high']

df['pollution'] = pd.Categorical(
    df['pollution'], 
    categories=pollution_order, 
    ordered=True
)

df = df.sort_values(by=['dataset', 'entity', 'pollution', 'metric_type'])

latex_code = generate_comparison_latex_prelim(df)

print(latex_code)

plot_degradation(df, "music", "prelim", "distillbert")
# Out:
# \begin{table}[h]
# \centering
# \caption{Comparison of F1 Scores: Baseline vs. Phase 1 vs. Phase 2 - Dataset music}
# \label{tab:f1_comparison_phases}
# \begin{tabular}{ll c cc c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{Phase 1}} & & \multicolumn{2}{c}{\textbf{Phase 2}} \\
# \cmidrule{4-5} \cmidrule{7-8} \cmidrule{10-11}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} \\
# \midrule
# area & source & & 0.8000 & 0.0000 & & \textbf{0.8075} & 0.0361 & & 0.7845 & 0.0403 \\
# area & low & & 0.7410 & 0.0000 & & \textbf{0.7790} & 0.0014 & & 0.7760 & 0.0410 \\
# area & medium & & \textbf{0.5150} & 0.0000 & & 0.4785 & 0.2779 & & 0.4065 & 0.1846 \\
# area & high & & \textbf{0.4870} & 0.0000 & & 0.2690 & 0.1853 & & 0.3420 & 0.0735 \\
# artist & source & & 0.9940 & 0.0000 & & 0.9900 & 0.0014 & & \textbf{0.9950} & 0.0014 \\
# artist & low & & 0.9960 & 0.0000 & & \textbf{1.0000} & 0.0000 & & 0.9980 & 0.0028 \\
# artist & medium & & 0.9960 & 0.0000 & & 0.9960 & 0.0028 & & \textbf{0.9980} & 0.0000 \\
# artist & high & & 0.9850 & 0.0000 & & 0.9895 & 0.0064 & & \textbf{0.9960} & 0.0028 \\
# artist_credit & source & & \textbf{0.9900} & 0.0000 & & 0.9840 & 0.0085 & & 0.9880 & 0.0028 \\
# artist_credit & low & & 0.9830 & 0.0000 & & 0.9835 & 0.0106 & & \textbf{0.9880} & 0.0028 \\
# artist_credit & medium & & 0.9650 & 0.0000 & & 0.9795 & 0.0049 & & \textbf{0.9910} & 0.0000 \\
# artist_credit & high & & 0.9170 & 0.0000 & & 0.9205 & 0.0035 & & \textbf{0.9560} & 0.0000 \\
# label & source & & 0.9550 & 0.0000 & & 0.9455 & 0.0120 & & \textbf{0.9590} & 0.0028 \\
# label & low & & 0.9340 & 0.0000 & & 0.9280 & 0.0156 & & \textbf{0.9405} & 0.0021 \\
# label & medium & & \textbf{0.8730} & 0.0000 & & 0.8690 & 0.0014 & & 0.8520 & 0.0099 \\
# label & high & & 0.7680 & 0.0000 & & \textbf{0.7795} & 0.0276 & & 0.7695 & 0.0233 \\
# medium & source & & 0.9630 & 0.0000 & & 0.9705 & 0.0007 & & \textbf{0.9870} & 0.0184 \\
# medium & low & & 0.9200 & 0.0000 & & 0.9140 & 0.0014 & & \textbf{0.9430} & 0.0113 \\
# medium & medium & & 0.8510 & 0.0000 & & 0.8650 & 0.0042 & & \textbf{0.9755} & 0.0078 \\
# medium & high & & 0.7470 & 0.0000 & & 0.7650 & 0.0141 & & \textbf{0.9520} & 0.0028 \\
# place & source & & \textbf{0.9650} & 0.0000 & & 0.9575 & 0.0163 & & 0.9620 & 0.0028 \\
# place & low & & \textbf{0.9600} & 0.0000 & & 0.9525 & 0.0106 & & 0.9440 & 0.0028 \\
# place & medium & & 0.9010 & 0.0000 & & \textbf{0.9295} & 0.0134 & & 0.9210 & 0.0028 \\
# place & high & & 0.8985 & 0.0035 & & 0.8985 & 0.0035 & & \textbf{0.8990} & 0.0014 \\
# recording & source & & 0.9930 & 0.0000 & & \textbf{0.9965} & 0.0035 & & 0.9925 & 0.0021 \\
# recording & low & & 0.9720 & 0.0000 & & 0.9815 & 0.0049 & & \textbf{0.9820} & 0.0028 \\
# recording & medium & & 0.9550 & 0.0000 & & 0.9620 & 0.0085 & & \textbf{0.9655} & 0.0035 \\
# recording & high & & 0.9160 & 0.0000 & & 0.9090 & 0.0156 & & \textbf{0.9455} & 0.0021 \\
# release & source & & 0.9810 & 0.0000 & & 0.9790 & 0.0000 & & \textbf{0.9825} & 0.0021 \\
# release & low & & \textbf{0.9820} & 0.0000 & & 0.9735 & 0.0049 & & 0.9765 & 0.0035 \\
# release & medium & & 0.9780 & 0.0000 & & 0.9755 & 0.0148 & & \textbf{0.9910} & 0.0099 \\
# release & high & & 0.9610 & 0.0000 & & 0.9525 & 0.0035 & & \textbf{0.9900} & 0.0014 \\
# release_group & source & & \textbf{0.9730} & 0.0000 & & 0.9630 & 0.0028 & & 0.9665 & 0.0120 \\
# release_group & low & & 0.9190 & 0.0000 & & 0.9245 & 0.0064 & & \textbf{0.9390} & 0.0283 \\
# release_group & medium & & 0.8930 & 0.0000 & & 0.8785 & 0.0007 & & \textbf{0.9430} & 0.0014 \\
# release_group & high & & 0.8040 & 0.0000 & & 0.7810 & 0.0283 & & \textbf{0.8775} & 0.0078 \\
# track & source & & 0.9980 & 0.0000 & & \textbf{0.9990} & 0.0000 & & \textbf{0.9990} & 0.0000 \\
# track & low & & 0.9960 & 0.0000 & & 0.9985 & 0.0007 & & \textbf{0.9995} & 0.0007 \\
# track & medium & & \textbf{0.9970} & 0.0000 & & 0.9945 & 0.0007 & & 0.9945 & 0.0007 \\
# track & high & & 0.9830 & 0.0000 & & 0.9825 & 0.0035 & & \textbf{0.9880} & 0.0014 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# ##  Main

# %%
df = query_metrics(music_distillbert2)

# 1. Define the logical order
pollution_order = ['source', 'low', 'medium', 'high']

# 2. Apply the categorical type to the column
df['pollution'] = pd.Categorical(
    df['pollution'], 
    categories=pollution_order, 
    ordered=True
)

# 3. Sort the DataFrame to reflect this order
# This ensures that when you generate the table or plot, the rows are in order
df = df.sort_values(by=['dataset', 'entity', 'pollution', 'metric_type'])

latex_code = generate_comparison_latex(df, test_metric='test')

print(latex_code)

plot_degradation(df, "music", "main", "distillbert")
# Out:
# \begin{table}[h]
# \centering
# \caption{Comparison of F1 Scores: Baseline vs. Test (test) - Dataset music}
# \label{tab:f1_comparison_auto}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{Test (Test)}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# area & source & & \textbf{0.8000} & 0.0000 & & 0.7920 & 0.0297 \\
# area & low & & 0.7410 & 0.0000 & & \textbf{0.7830} & 0.0311 \\
# area & medium & & \textbf{0.5150} & 0.0000 & & 0.4280 & 0.2150 \\
# area & high & & \textbf{0.4870} & 0.0000 & & 0.3775 & 0.0856 \\
# artist & source & & \textbf{0.9940} & 0.0000 & & 0.8210 & 0.0071 \\
# artist & low & & \textbf{0.9960} & 0.0000 & & 0.8255 & 0.1365 \\
# artist & medium & & \textbf{0.9960} & 0.0000 & & 0.5655 & 0.0191 \\
# artist & high & & \textbf{0.9850} & 0.0000 & & 0.8155 & 0.0021 \\
# artist_credit & source & & \textbf{0.9900} & 0.0000 & & 0.9880 & 0.0028 \\
# artist_credit & low & & 0.9830 & 0.0000 & & \textbf{0.9880} & 0.0028 \\
# artist_credit & medium & & \textbf{0.9650} & 0.0000 & & 0.6255 & 0.1336 \\
# artist_credit & high & & \textbf{0.9170} & 0.0000 & & 0.8870 & 0.0651 \\
# label & source & & \textbf{0.9550} & 0.0000 & & 0.9455 & 0.0021 \\
# label & low & & \textbf{0.9340} & 0.0000 & & 0.9315 & 0.0035 \\
# label & medium & & \textbf{0.8730} & 0.0000 & & 0.8585 & 0.0064 \\
# label & high & & \textbf{0.7680} & 0.0000 & & 0.7135 & 0.0247 \\
# medium & source & & 0.9630 & 0.0000 & & \textbf{0.9890} & 0.0156 \\
# medium & low & & 0.9200 & 0.0000 & & \textbf{0.9750} & 0.0085 \\
# medium & medium & & 0.8510 & 0.0000 & & \textbf{0.9850} & 0.0057 \\
# medium & high & & 0.7470 & 0.0000 & & \textbf{0.9475} & 0.0219 \\
# place & source & & \textbf{0.9650} & 0.0000 & & 0.9350 & 0.0141 \\
# place & low & & \textbf{0.9600} & 0.0000 & & 0.9395 & 0.0219 \\
# place & medium & & \textbf{0.9010} & 0.0000 & & 0.8515 & 0.0813 \\
# place & high & & \textbf{0.8985} & 0.0035 & & 0.7795 & 0.0445 \\
# recording & source & & 0.9930 & 0.0000 & & \textbf{0.9945} & 0.0007 \\
# recording & low & & 0.9720 & 0.0000 & & \textbf{0.9820} & 0.0028 \\
# recording & medium & & 0.9550 & 0.0000 & & \textbf{0.9730} & 0.0198 \\
# recording & high & & 0.9160 & 0.0000 & & \textbf{0.9685} & 0.0007 \\
# release & source & & \textbf{0.9810} & 0.0000 & & 0.9500 & 0.0170 \\
# release & low & & \textbf{0.9820} & 0.0000 & & 0.8930 & 0.0523 \\
# release & medium & & \textbf{0.9780} & 0.0000 & & 0.9540 & 0.0113 \\
# release & high & & \textbf{0.9610} & 0.0000 & & 0.9120 & 0.0905 \\
# release_group & source & & \textbf{0.9730} & 0.0000 & & 0.9705 & 0.0078 \\
# release_group & low & & 0.9190 & 0.0000 & & \textbf{0.9465} & 0.0262 \\
# release_group & medium & & 0.8930 & 0.0000 & & \textbf{0.9310} & 0.0156 \\
# release_group & high & & 0.8040 & 0.0000 & & \textbf{0.8245} & 0.0049 \\
# track & source & & 0.9980 & 0.0000 & & \textbf{0.9990} & 0.0000 \\
# track & low & & 0.9960 & 0.0000 & & \textbf{0.9990} & 0.0000 \\
# track & medium & & \textbf{0.9970} & 0.0000 & & 0.9935 & 0.0007 \\
# track & high & & 0.9830 & 0.0000 & & \textbf{0.9920} & 0.0000 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
# music_distillbert2 = 9791153
pokemon_distillbert = 9796515
df = query_prelimary(pokemon_distillbert)

pollution_order = ['source', 'low', 'medium', 'high']

df['pollution'] = pd.Categorical(
    df['pollution'], 
    categories=pollution_order, 
    ordered=True
)

df = df.sort_values(by=['dataset', 'entity', 'pollution', 'metric_type'])

latex_code = generate_comparison_latex_prelim(df)

print(latex_code)

plot_degradation(df, "pokemon", "prelim", "distillbert")
# Out:
# \begin{table}[h]
# \centering
# \caption{Comparison of F1 Scores: Baseline vs. Phase 1 vs. Phase 2 - Dataset music}
# \label{tab:f1_comparison_phases}
# \begin{tabular}{ll c cc c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{Phase 1}} & & \multicolumn{2}{c}{\textbf{Phase 2}} \\
# \cmidrule{4-5} \cmidrule{7-8} \cmidrule{10-11}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} \\
# \midrule
# ability & source & & 0.9940 & 0.0000 & & \textbf{0.9970} & 0.0042 & & 0.9910 & 0.0127 \\
# ability & low & & 0.9690 & 0.0000 & & 0.9810 & 0.0184 & & \textbf{0.9875} & 0.0092 \\
# ability & medium & & 0.9290 & 0.0000 & & \textbf{0.9455} & 0.0177 & & 0.9330 & 0.0000 \\
# ability & high & & 0.8910 & 0.0000 & & 0.8965 & 0.0021 & & \textbf{0.9245} & 0.0106 \\
# item & source & & 0.9410 & 0.0000 & & 0.9745 & 0.0205 & & \textbf{0.9860} & 0.0042 \\
# item & low & & 0.9710 & 0.0000 & & 0.9615 & 0.0247 & & \textbf{0.9730} & 0.0042 \\
# item & medium & & 0.9210 & nan & & 0.9340 & 0.0212 & & \textbf{0.9485} & 0.0078 \\
# item & high & & \textbf{0.9020} & 0.0000 & & 0.8810 & 0.0410 & & 0.8945 & 0.0276 \\
# move & source & & 0.9810 & nan & & 0.9915 & 0.0007 & & \textbf{0.9950} & 0.0042 \\
# move & low & & \textbf{0.9920} & nan & & 0.9850 & 0.0028 & & \textbf{0.9920} & 0.0042 \\
# move & medium & & 0.9870 & nan & & 0.9870 & 0.0099 & & \textbf{0.9895} & 0.0078 \\
# move & high & & \textbf{0.9670} & 0.0000 & & 0.9630 & 0.0156 & & 0.9655 & 0.0148 \\
# pokemon & source & & 0.9800 & 0.0000 & & 0.9845 & 0.0078 & & \textbf{0.9860} & 0.0014 \\
# pokemon & low & & 0.9640 & 0.0000 & & 0.9715 & 0.0106 & & \textbf{0.9755} & 0.0064 \\
# pokemon & medium & & 0.9520 & 0.0000 & & 0.9430 & 0.0014 & & \textbf{0.9585} & 0.0049 \\
# pokemon & high & & 0.8860 & 0.0000 & & 0.8900 & 0.0099 & & \textbf{0.9125} & 0.0148 \\
# species & source & & \textbf{0.9940} & nan & & 0.8650 & 0.1739 & & 0.9060 & 0.1117 \\
# species & low & & \textbf{0.9800} & nan & & 0.8645 & 0.1676 & & 0.8960 & 0.1216 \\
# species & medium & & \textbf{0.9910} & nan & & 0.8360 & 0.2065 & & 0.8540 & 0.1810 \\
# species & high & & \textbf{0.9810} & 0.0000 & & 0.8830 & 0.1004 & & 0.9225 & 0.0672 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %%
df = query_metrics(pokemon_distillbert)

# 1. Define the logical order
pollution_order = ['source', 'low', 'medium', 'high']

# 2. Apply the categorical type to the column
df['pollution'] = pd.Categorical(
    df['pollution'], 
    categories=pollution_order, 
    ordered=True
)

# 3. Sort the DataFrame to reflect this order
# This ensures that when you generate the table or plot, the rows are in order
df = df.sort_values(by=['dataset', 'entity', 'pollution', 'metric_type'])

latex_code = generate_comparison_latex(df, test_metric='test')

print(latex_code)

plot_degradation(df, "pokemon", "main", "distillbert")
# Out:
# \begin{table}[h]
# \centering
# \caption{Comparison of F1 Scores: Baseline vs. Test (test) - Dataset music}
# \label{tab:f1_comparison_auto}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{Test (Test)}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# ability & source & & \textbf{0.9940} & 0.0000 & & 0.9735 & 0.0375 \\
# ability & low & & 0.9690 & 0.0000 & & \textbf{0.9730} & 0.0297 \\
# ability & medium & & \textbf{0.9290} & 0.0000 & & 0.9120 & 0.0141 \\
# ability & high & & \textbf{0.8910} & 0.0000 & & 0.8500 & 0.0410 \\
# item & source & & 0.9410 & 0.0000 & & \textbf{0.9535} & 0.0177 \\
# item & low & & \textbf{0.9710} & 0.0000 & & 0.9355 & 0.0233 \\
# item & medium & & \textbf{0.9210} & nan & & 0.9190 & 0.0057 \\
# item & high & & \textbf{0.9020} & 0.0000 & & 0.8615 & 0.0219 \\
# move & source & & \textbf{0.9810} & nan & & 0.9800 & 0.0198 \\
# move & low & & \textbf{0.9920} & nan & & 0.9745 & 0.0035 \\
# move & medium & & \textbf{0.9870} & nan & & 0.9745 & 0.0163 \\
# move & high & & \textbf{0.9670} & 0.0000 & & 0.9510 & 0.0042 \\
# pokemon & source & & 0.9800 & 0.0000 & & 0.9800 & 0.0042 \\
# pokemon & low & & 0.9640 & 0.0000 & & \textbf{0.9705} & 0.0049 \\
# pokemon & medium & & 0.9520 & 0.0000 & & \textbf{0.9540} & 0.0014 \\
# pokemon & high & & 0.8860 & 0.0000 & & \textbf{0.9100} & 0.0127 \\
# species & source & & \textbf{0.9940} & nan & & 0.8695 & 0.1209 \\
# species & low & & \textbf{0.9800} & nan & & 0.8675 & 0.1181 \\
# species & medium & & \textbf{0.9910} & nan & & 0.8280 & 0.2051 \\
# species & high & & \textbf{0.9810} & 0.0000 & & 0.8650 & 0.0509 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# # 9796616
#
# learning rate refinetune : 2e-5

# %%
jobid = 9796616

df = query_metrics(jobid)
# 1. Define the logical order
pollution_order = ['source', 'low', 'medium', 'high']

# 2. Apply the categorical type to the column
df['pollution'] = pd.Categorical(
    df['pollution'], 
    categories=pollution_order, 
    ordered=True
)

# 3. Sort the DataFrame to reflect this order
# This ensures that when you generate the table or plot, the rows are in order
df = df.sort_values(by=['dataset', 'entity', 'pollution', 'metric_type'])
latex_code = generate_comparison_latex(df, test_metric='test')


print(latex_code)

df = query_metrics_individual(jobid)
plot_degradation_boxplot(df, "music", "main", "roberta")
# Out:
# \begin{table}[h]
# \centering
# \caption{Main Experiment: Baseline vs. RETEM - Dataset music}
# \label{tab:main_exp_}}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{RETEM}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# area & source & & 0.8066 & 0.0148 & & nan & nan \\
# area & low & & 0.7610 & 0.0274 & & \textbf{0.7985} & 0.0332 \\
# area & medium & & \textbf{0.5444} & 0.0268 & & 0.4842 & 0.1767 \\
# area & high & & \textbf{0.5062} & 0.0452 & & 0.4650 & 0.1795 \\
# artist & source & & 0.9972 & 0.0018 & & nan & nan \\
# artist & low & & \textbf{0.9968} & 0.0011 & & 0.8385 & 0.1365 \\
# artist & medium & & \textbf{0.9968} & 0.0044 & & 0.7346 & 0.1050 \\
# artist & high & & \textbf{0.9952} & 0.0018 & & 0.7532 & 0.1138 \\
# artist_credit & source & & 0.9892 & 0.0018 & & nan & nan \\
# artist_credit & low & & 0.9794 & 0.0049 & & \textbf{0.9865} & 0.0049 \\
# artist_credit & medium & & \textbf{0.9740} & 0.0082 & & 0.9016 & 0.0870 \\
# artist_credit & high & & \textbf{0.9228} & 0.0040 & & 0.8072 & 0.0535 \\
# label & source & & 0.9540 & 0.0022 & & nan & nan \\
# label & low & & \textbf{0.9356} & 0.0022 & & 0.8990 & 0.0283 \\
# label & medium & & \textbf{0.8664} & 0.0060 & & 0.8524 & 0.0263 \\
# label & high & & \textbf{0.7394} & 0.0300 & & 0.7180 & 0.0239 \\
# medium & source & & 0.9740 & 0.0000 & & nan & nan \\
# medium & low & & 0.9196 & 0.0005 & & \textbf{0.9830} & 0.0085 \\
# medium & medium & & 0.8540 & 0.0027 & & \textbf{0.9588} & 0.0344 \\
# medium & high & & 0.7700 & 0.0022 & & \textbf{0.8636} & 0.1286 \\
# place & source & & 0.9616 & 0.0076 & & nan & nan \\
# place & low & & \textbf{0.9560} & 0.0055 & & 0.8995 & 0.0247 \\
# place & medium & & \textbf{0.9160} & 0.0137 & & 0.8558 & 0.0493 \\
# place & high & & \textbf{0.8896} & 0.0165 & & 0.7680 & 0.0392 \\
# recording & source & & 0.9936 & 0.0013 & & nan & nan \\
# recording & low & & 0.9766 & 0.0005 & & \textbf{0.9830} & 0.0014 \\
# recording & medium & & 0.9544 & 0.0005 & & \textbf{0.9644} & 0.0156 \\
# recording & high & & 0.9132 & 0.0018 & & \textbf{0.9630} & 0.0071 \\
# release & source & & 0.9796 & 0.0031 & & nan & nan \\
# release & low & & \textbf{0.9800} & 0.0027 & & 0.8970 & 0.0283 \\
# release & medium & & \textbf{0.9774} & 0.0005 & & 0.9408 & 0.0591 \\
# release & high & & \textbf{0.9608} & 0.0004 & & 0.8478 & 0.1263 \\
# release_group & source & & 0.9720 & 0.0022 & & nan & nan \\
# release_group & low & & 0.9298 & 0.0016 & & \textbf{0.9575} & 0.0290 \\
# release_group & medium & & 0.8960 & 0.0027 & & \textbf{0.9044} & 0.0308 \\
# release_group & high & & 0.7840 & 0.0067 & & \textbf{0.8266} & 0.0295 \\
# track & source & & 0.9992 & 0.0004 & & nan & nan \\
# track & low & & \textbf{1.0000} & 0.0000 & & 0.9995 & 0.0007 \\
# track & medium & & \textbf{0.9958} & 0.0011 & & 0.9924 & 0.0047 \\
# track & high & & 0.9800 & nan & & \textbf{0.9868} & 0.0066 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# # 9798848

# %%
jobid = 9798848
df = query_metrics(jobid)

latex_code = generate_comparison_latex(df, test_metric='test')

print(latex_code)

df = query_metrics_individual(jobid)

display(df)

plot_degradation_boxplot(df, "music", "main", "roberta")
# Out:
# \begin{table}[h]
# \centering
# \caption{Main Experiment: Baseline vs. RETEM - Dataset music}
# \label{tab:main_exp_}}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{RETEM}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# area & source & & \textbf{0.9802} & 0.0219 & & 0.9618 & 0.0325 \\
# area & low & & \textbf{0.9160} & 0.0274 & & 0.9024 & 0.0836 \\
# area & medium & & 0.6660 & 0.1706 & & \textbf{0.8758} & 0.0336 \\
# area & high & & 0.4986 & 0.1847 & & \textbf{0.6238} & 0.2146 \\
# artist & source & & \textbf{0.9952} & 0.0027 & & 0.9200 & 0.0663 \\
# artist & low & & \textbf{0.9972} & 0.0011 & & 0.8614 & 0.1440 \\
# artist & medium & & \textbf{0.9956} & 0.0009 & & 0.9665 & 0.0272 \\
# artist & high & & \textbf{0.9956} & 0.0026 & & 0.8358 & 0.2082 \\
# artist_credit & source & & 0.9970 & nan & & \textbf{0.9972} & 0.0018 \\
# artist_credit & low & & 0.9900 & 0.0027 & & \textbf{0.9916} & 0.0065 \\
# artist_credit & medium & & 0.9896 & 0.0026 & & \textbf{0.9898} & 0.0034 \\
# artist_credit & high & & \textbf{0.9422} & 0.0094 & & 0.8734 & 0.1818 \\
# label & source & & \textbf{0.9754} & 0.0054 & & 0.9670 & 0.0056 \\
# label & low & & \textbf{0.9540} & 0.0000 & & 0.9368 & 0.0134 \\
# label & medium & & 0.8864 & 0.0071 & & \textbf{0.8898} & 0.0257 \\
# label & high & & 0.7452 & 0.1936 & & \textbf{0.7872} & 0.0793 \\
# medium & source & & 0.8220 & 0.0850 & & \textbf{1.0000} & 0.0000 \\
# medium & low & & 0.9110 & 0.0055 & & \textbf{0.9786} & 0.0083 \\
# medium & medium & & 0.8568 & 0.0102 & & \textbf{0.9898} & 0.0078 \\
# medium & high & & 0.7658 & 0.0294 & & \textbf{0.9624} & 0.0202 \\
# place & source & & \textbf{0.9760} & 0.0022 & & 0.9696 & 0.0065 \\
# place & low & & \textbf{0.9656} & 0.0060 & & 0.9598 & 0.0191 \\
# place & medium & & \textbf{0.9414} & 0.0048 & & 0.9347 & 0.0087 \\
# place & high & & \textbf{0.8692} & 0.0561 & & 0.7914 & 0.0950 \\
# recording & source & & \textbf{0.9988} & 0.0004 & & 0.9944 & 0.0065 \\
# recording & low & & 0.9828 & 0.0044 & & \textbf{0.9846} & 0.0049 \\
# recording & medium & & 0.9710 & 0.0045 & & \textbf{0.9828} & 0.0138 \\
# recording & high & & 0.9166 & 0.0057 & & \textbf{0.9666} & 0.0086 \\
# release & source & & 0.9810 & 0.0157 & & 0.9810 & 0.0128 \\
# release & low & & \textbf{0.9418} & 0.0422 & & 0.9412 & 0.0449 \\
# release & medium & & \textbf{0.9888} & 0.0039 & & 0.9728 & 0.0059 \\
# release & high & & 0.9776 & 0.0067 & & \textbf{0.9790} & 0.0103 \\
# release_group & source & & \textbf{0.9858} & 0.0049 & & 0.9842 & 0.0057 \\
# release_group & low & & 0.9610 & 0.0027 & & \textbf{0.9658} & 0.0123 \\
# release_group & medium & & 0.9168 & 0.0101 & & \textbf{0.9465} & 0.0165 \\
# release_group & high & & \textbf{0.8246} & 0.0144 & & 0.7832 & 0.2182 \\
# track & source & & \textbf{1.0000} & 0.0000 & & 0.9988 & 0.0018 \\
# track & low & & 0.9986 & 0.0005 & & \textbf{0.9996} & 0.0005 \\
# track & medium & & 0.9964 & 0.0022 & & \textbf{0.9968} & 0.0026 \\
# track & high & & 0.9872 & 0.0016 & & \textbf{0.9914} & 0.0077 \\
# \bottomrule
# \end{tabular}
# \end{table}
#     dataset entity metric_type  f1_score  seed  train_size pollution  epochs
# 0     music   area    baseline     0.990     4         1.0    source      10
# 1     music   area    baseline     0.990     2         1.0    source      10
# 2     music   area    baseline     0.990     1         1.0    source      10
# 3     music   area    baseline     0.990     3         1.0    source      10
# 4     music   area    baseline     0.936     1         1.0       low      10
# ..      ...    ...         ...       ...   ...         ...       ...     ...
# 385   music  track        test     0.996     1         1.0      high      10
# 386   music  track        test     0.996     2         1.0      high      10
# 387   music  track        test     0.995     3         1.0      high      10
# 388   music  track        test     0.978     4         1.0      high      10
# 389   music  track        test     0.992     5         1.0      high      10
#
# [390 rows x 8 columns]

# %% [markdown]
# # 9799645
#
# - Pokemon
#
# - 5 Seeds
#
# - DITTO_CONFIG = {
#     "batch_size": 32,
#     "max_len": 512,
#     phase1: "learning_rate": 3e-5,
#     phase2: 2e-5
#     "epochs": 10,
#     "lm": "roberta",  # roberta
# }

# %%
jobid = 9799645

df = query_metrics(jobid)
# 1. Define the logical order
pollution_order = ['source', 'low', 'medium', 'high']

# 2. Apply the categorical type to the column
df['pollution'] = pd.Categorical(
    df['pollution'], 
    categories=pollution_order, 
    ordered=True
)

# 3. Sort the DataFrame to reflect this order
# This ensures that when you generate the table or plot, the rows are in order
df = df.sort_values(by=['dataset', 'entity', 'pollution', 'metric_type'])
latex_code = generate_comparison_latex(df, test_metric='test')


print(latex_code)

df = query_metrics_individual(jobid)
plot_degradation_boxplot(df, "music", "main", "roberta")
# Out:
# \begin{table}[h]
# \centering
# \caption{Main Experiment: Baseline vs. RETEM - Dataset music}
# \label{tab:main_exp_}}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{RETEM}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# ability & source & & \textbf{0.9988} & 0.0027 & & 0.9858 & 0.0223 \\
# ability & low & & 0.9824 & 0.0031 & & \textbf{0.9878} & 0.0108 \\
# ability & medium & & 0.9312 & 0.0126 & & \textbf{0.9316} & 0.0063 \\
# ability & high & & 0.7172 & 0.3029 & & \textbf{0.9068} & 0.0304 \\
# item & source & & 0.9836 & 0.0080 & & \textbf{0.9962} & 0.0022 \\
# item & low & & 0.9754 & 0.0050 & & \textbf{0.9780} & 0.0042 \\
# item & medium & & \textbf{0.9632} & 0.0033 & & 0.9562 & 0.0063 \\
# item & high & & 0.8020 & 0.2248 & & \textbf{0.9008} & 0.0269 \\
# move & source & & \textbf{0.9980} & nan & & 0.9920 & 0.0047 \\
# move & low & & \textbf{0.9952} & 0.0038 & & 0.9914 & 0.0043 \\
# move & medium & & \textbf{0.9928} & 0.0060 & & 0.9900 & 0.0041 \\
# move & high & & 0.9772 & 0.0183 & & \textbf{0.9786} & 0.0140 \\
# pokemon & source & & \textbf{0.9944} & 0.0009 & & 0.9866 & 0.0078 \\
# pokemon & low & & \textbf{0.9804} & 0.0088 & & 0.9752 & 0.0044 \\
# pokemon & medium & & \textbf{0.9632} & 0.0038 & & 0.9630 & 0.0064 \\
# pokemon & high & & 0.8434 & 0.1564 & & \textbf{0.9112} & 0.0273 \\
# species & source & & 1.0000 & 0.0000 & & 1.0000 & 0.0000 \\
# species & low & & 0.9902 & 0.0113 & & \textbf{0.9962} & 0.0047 \\
# species & medium & & \textbf{0.9910} & 0.0091 & & 0.9896 & 0.0048 \\
# species & high & & \textbf{0.9844} & 0.0146 & & 0.9838 & 0.0240 \\
# \bottomrule
# \end{tabular}
# \end{table}
