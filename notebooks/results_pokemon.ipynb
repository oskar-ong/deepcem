# %%
from results_analysis import analyze_main

analyze_main(9796515, "pokemon", "roberta")
# Out:
# \begin{table}[h]
# \centering
# \caption{Main Experiment: Baseline vs. RETEM - Dataset music}
# \label{tab:main_exp_}}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{RETEM}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# ability & source & & \textbf{0.9940} & 0.0000 & & 0.9735 & 0.0375 \\
# ability & low & & 0.9690 & 0.0000 & & \textbf{0.9730} & 0.0297 \\
# ability & medium & & \textbf{0.9290} & 0.0000 & & 0.9120 & 0.0141 \\
# ability & high & & \textbf{0.8910} & 0.0000 & & 0.8500 & 0.0410 \\
# item & source & & 0.9410 & 0.0000 & & \textbf{0.9535} & 0.0177 \\
# item & low & & \textbf{0.9710} & 0.0000 & & 0.9355 & 0.0233 \\
# item & medium & & \textbf{0.9210} & nan & & 0.9190 & 0.0057 \\
# item & high & & \textbf{0.9020} & 0.0000 & & 0.8615 & 0.0219 \\
# move & source & & \textbf{0.9810} & nan & & 0.9800 & 0.0198 \\
# move & low & & \textbf{0.9920} & nan & & 0.9745 & 0.0035 \\
# move & medium & & \textbf{0.9870} & nan & & 0.9745 & 0.0163 \\
# move & high & & \textbf{0.9670} & 0.0000 & & 0.9510 & 0.0042 \\
# pokemon & source & & 0.9800 & 0.0000 & & 0.9800 & 0.0042 \\
# pokemon & low & & 0.9640 & 0.0000 & & \textbf{0.9705} & 0.0049 \\
# pokemon & medium & & 0.9520 & 0.0000 & & \textbf{0.9540} & 0.0014 \\
# pokemon & high & & 0.8860 & 0.0000 & & \textbf{0.9100} & 0.0127 \\
# species & source & & \textbf{0.9940} & nan & & 0.8695 & 0.1209 \\
# species & low & & \textbf{0.9800} & nan & & 0.8675 & 0.1181 \\
# species & medium & & \textbf{0.9910} & nan & & 0.8280 & 0.2051 \\
# species & high & & \textbf{0.9810} & 0.0000 & & 0.8650 & 0.0509 \\
# \bottomrule
# \end{tabular}
# \end{table}
#     dataset   entity metric_type  mean_f1    std_f1  num_seeds  train_size  \
# 0   pokemon  ability    baseline   0.8910  0.000000          2         1.0
# 1   pokemon  ability    baseline   0.9690  0.000000          2         1.0
# 2   pokemon  ability    baseline   0.9290  0.000000          2         1.0
# 3   pokemon  ability    baseline   0.9940  0.000000          2         1.0
# 4   pokemon  ability        test   0.8500  0.041012          2         1.0
# 5   pokemon  ability        test   0.9730  0.029698          2         1.0
# 6   pokemon  ability        test   0.9120  0.014142          2         1.0
# 7   pokemon  ability        test   0.9735  0.037477          2         1.0
# 8   pokemon     item    baseline   0.9020  0.000000          2         1.0
# 9   pokemon     item    baseline   0.9710  0.000000          2         1.0
# 10  pokemon     item    baseline   0.9210       NaN          1         1.0
# 11  pokemon     item    baseline   0.9410  0.000000          2         1.0
# 12  pokemon     item        test   0.8615  0.021920          2         1.0
# 13  pokemon     item        test   0.9355  0.023335          2         1.0
# 14  pokemon     item        test   0.9190  0.005657          2         1.0
# 15  pokemon     item        test   0.9535  0.017678          2         1.0
# 16  pokemon     move    baseline   0.9670  0.000000          2         1.0
# 17  pokemon     move    baseline   0.9920       NaN          1         1.0
# 18  pokemon     move    baseline   0.9870       NaN          1         1.0
# 19  pokemon     move    baseline   0.9810       NaN          1         1.0
# 20  pokemon     move        test   0.9510  0.004243          2         1.0
# 21  pokemon     move        test   0.9745  0.003536          2         1.0
# 22  pokemon     move        test   0.9745  0.016263          2         1.0
# 23  pokemon     move        test   0.9800  0.019799          2         1.0
# 24  pokemon  pokemon    baseline   0.8860  0.000000          2         1.0
# 25  pokemon  pokemon    baseline   0.9640  0.000000          2         1.0
# 26  pokemon  pokemon    baseline   0.9520  0.000000          2         1.0
# 27  pokemon  pokemon    baseline   0.9800  0.000000          2         1.0
# 28  pokemon  pokemon        test   0.9100  0.012728          2         1.0
# 29  pokemon  pokemon        test   0.9705  0.004950          2         1.0
# 30  pokemon  pokemon        test   0.9540  0.001414          2         1.0
# 31  pokemon  pokemon        test   0.9800  0.004243          2         1.0
# 32  pokemon  species    baseline   0.9810  0.000000          2         1.0
# 33  pokemon  species    baseline   0.9800       NaN          1         1.0
# 34  pokemon  species    baseline   0.9910       NaN          1         1.0
# 35  pokemon  species    baseline   0.9940       NaN          1         1.0
# 36  pokemon  species        test   0.8650  0.050912          2         1.0
# 37  pokemon  species        test   0.8675  0.118087          2         1.0
# 38  pokemon  species        test   0.8280  0.205061          2         1.0
# 39  pokemon  species        test   0.8695  0.120915          2         1.0
#
#    pollution  epochs
# 0       high      10
# 1        low      10
# 2     medium      10
# 3     source      10
# 4       high      10
# 5        low      10
# 6     medium      10
# 7     source      10
# 8       high      10
# 9        low      10
# 10    medium      10
# 11    source      10
# 12      high      10
# 13       low      10
# 14    medium      10
# 15    source      10
# 16      high      10
# 17       low      10
# 18    medium      10
# 19    source      10
# 20      high      10
# 21       low      10
# 22    medium      10
# 23    source      10
# 24      high      10
# 25       low      10
# 26    medium      10
# 27    source      10
# 28      high      10
# 29       low      10
# 30    medium      10
# 31    source      10
# 32      high      10
# 33       low      10
# 34    medium      10
# 35    source      10
# 36      high      10
# 37       low      10
# 38    medium      10
# 39    source      10

# %%
from results_analysis import analyze_prelim


analyze_prelim(9796515, "pokemon", "distillbert")
# Out:
# \begin{table}[h]
# \centering
# \caption{Baseline (Ditto pure) vs. Phase 1 (Empty Relational Scores) vs. Phase 2 (Relational Scores based on Ground-Truth) - Dataset pokemon}
# \label{tab:prelim_exp_}
# \begin{tabular}{ll c cc c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{Phase 1}} & & \multicolumn{2}{c}{\textbf{Phase 2}} \\
# \cmidrule{4-5} \cmidrule{7-8} \cmidrule{10-11}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} \\
# \midrule
# ability & source & & 0.9940 & 0.0000 & & \textbf{0.9970} & 0.0042 & & 0.9910 & 0.0127 \\
# ability & low & & 0.9690 & 0.0000 & & 0.9810 & 0.0184 & & \textbf{0.9875} & 0.0092 \\
# ability & medium & & 0.9290 & 0.0000 & & \textbf{0.9455} & 0.0177 & & 0.9330 & 0.0000 \\
# ability & high & & 0.8910 & 0.0000 & & 0.8965 & 0.0021 & & \textbf{0.9245} & 0.0106 \\
# item & source & & 0.9410 & 0.0000 & & 0.9745 & 0.0205 & & \textbf{0.9860} & 0.0042 \\
# item & low & & 0.9710 & 0.0000 & & 0.9615 & 0.0247 & & \textbf{0.9730} & 0.0042 \\
# item & medium & & 0.9210 & nan & & 0.9340 & 0.0212 & & \textbf{0.9485} & 0.0078 \\
# item & high & & \textbf{0.9020} & 0.0000 & & 0.8810 & 0.0410 & & 0.8945 & 0.0276 \\
# move & source & & 0.9810 & nan & & 0.9915 & 0.0007 & & \textbf{0.9950} & 0.0042 \\
# move & low & & \textbf{0.9920} & nan & & 0.9850 & 0.0028 & & \textbf{0.9920} & 0.0042 \\
# move & medium & & 0.9870 & nan & & 0.9870 & 0.0099 & & \textbf{0.9895} & 0.0078 \\
# move & high & & \textbf{0.9670} & 0.0000 & & 0.9630 & 0.0156 & & 0.9655 & 0.0148 \\
# pokemon & source & & 0.9800 & 0.0000 & & 0.9845 & 0.0078 & & \textbf{0.9860} & 0.0014 \\
# pokemon & low & & 0.9640 & 0.0000 & & 0.9715 & 0.0106 & & \textbf{0.9755} & 0.0064 \\
# pokemon & medium & & 0.9520 & 0.0000 & & 0.9430 & 0.0014 & & \textbf{0.9585} & 0.0049 \\
# pokemon & high & & 0.8860 & 0.0000 & & 0.8900 & 0.0099 & & \textbf{0.9125} & 0.0148 \\
# species & source & & \textbf{0.9940} & nan & & 0.8650 & 0.1739 & & 0.9060 & 0.1117 \\
# species & low & & \textbf{0.9800} & nan & & 0.8645 & 0.1676 & & 0.8960 & 0.1216 \\
# species & medium & & \textbf{0.9910} & nan & & 0.8360 & 0.2065 & & 0.8540 & 0.1810 \\
# species & high & & \textbf{0.9810} & 0.0000 & & 0.8830 & 0.1004 & & 0.9225 & 0.0672 \\
# \bottomrule
# \end{tabular}
# \end{table}

# %% [markdown]
# # 9799645
#
# - Pokemon
#
# - 5 Seeds
#
# - DITTO_CONFIG = {
#     "batch_size": 32,
#     "max_len": 512,
#     phase1: "learning_rate": 3e-5,
#     phase2: 2e-5
#     "epochs": 10,
#     "lm": "roberta",  # roberta
# }

# %%
jobid = 9799645

analyze_main(jobid, "pokemon", "roberta")

from analyze_val_scores import process_directory


df = process_directory("../slurm_logs", jobid)

display(df)
# Out:
# \begin{table}[h]
# \centering
# \caption{Main Experiment: Baseline vs. RETEM - Dataset music}
# \label{tab:main_exp_}}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{RETEM}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# ability & source & & \textbf{0.9988} & 0.0027 & & 0.9858 & 0.0223 \\
# ability & low & & 0.9824 & 0.0031 & & \textbf{0.9878} & 0.0108 \\
# ability & medium & & 0.9312 & 0.0126 & & \textbf{0.9316} & 0.0063 \\
# ability & high & & 0.7172 & 0.3029 & & \textbf{0.9068} & 0.0304 \\
# item & source & & 0.9836 & 0.0080 & & \textbf{0.9962} & 0.0022 \\
# item & low & & 0.9754 & 0.0050 & & \textbf{0.9780} & 0.0042 \\
# item & medium & & \textbf{0.9632} & 0.0033 & & 0.9562 & 0.0063 \\
# item & high & & 0.8020 & 0.2248 & & \textbf{0.9008} & 0.0269 \\
# move & source & & \textbf{0.9980} & nan & & 0.9920 & 0.0047 \\
# move & low & & \textbf{0.9952} & 0.0038 & & 0.9914 & 0.0043 \\
# move & medium & & \textbf{0.9928} & 0.0060 & & 0.9900 & 0.0041 \\
# move & high & & 0.9772 & 0.0183 & & \textbf{0.9786} & 0.0140 \\
# pokemon & source & & \textbf{0.9944} & 0.0009 & & 0.9866 & 0.0078 \\
# pokemon & low & & \textbf{0.9804} & 0.0088 & & 0.9752 & 0.0044 \\
# pokemon & medium & & \textbf{0.9632} & 0.0038 & & 0.9630 & 0.0064 \\
# pokemon & high & & 0.8434 & 0.1564 & & \textbf{0.9112} & 0.0273 \\
# species & source & & 1.0000 & 0.0000 & & 1.0000 & 0.0000 \\
# species & low & & 0.9902 & 0.0113 & & \textbf{0.9962} & 0.0047 \\
# species & medium & & \textbf{0.9910} & 0.0091 & & 0.9896 & 0.0048 \\
# species & high & & \textbf{0.9844} & 0.0146 & & 0.9838 & 0.0240 \\
# \bottomrule
# \end{tabular}
# \end{table}
# threshold for val f1: 0.9682
#      entity       val  baseline   test  baseline_is_higher
# 71     item  0.399423     0.400  0.880                   0
# 0   ability  0.409639     0.400  0.907                   0
# 75  ability  0.422764     0.372  0.924                   0
# 78  pokemon  0.607330     0.564  0.864                   0
# 79  species  0.883562     0.986  0.992                   0
# ..      ...       ...       ...    ...                 ...
# 47     move  1.000000     0.998  0.988                   1
# 52     move  1.000000     0.991  0.995                   0
# 54  species  1.000000     1.000  0.997                   1
# 82     move  1.000000     0.998  0.997                   1
# 24  species  1.000000     1.000  1.000                   0
#
# [100 rows x 5 columns]

# %% [markdown]
# # 9807012

# %%
from results_analysis import investigate_outliers, plot_retem_vs_base, analyze_main, analyze_prelim


df = analyze_main(9807012, "pokemon", "roberta")

high_sd_df = df[df['std_f1'] > 0.05].copy()

display(high_sd_df)

outlier_details = investigate_outliers(high_sd_df.iloc[4], 9807012)
print(outlier_details)


analyze_prelim(9807012, "pokemon", "roberta")

plot_retem_vs_base(9807012, "Pokemon")
# Out:
# \begin{table}[h]
# \centering
# \caption{Main Experiment: Baseline vs. RETEM - Dataset music}
# \label{tab:main_exp_}}
# \begin{tabular}{ll c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{RETEM}} \\
# \cmidrule{4-5} \cmidrule{7-8}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean F1} & \textbf{SD} & & \textbf{Mean F1} & \textbf{SD} \\
# \midrule
# ability & source & & 0.9838 & 0.0018 & & \textbf{0.9884} & 0.0170 \\
# ability & low & & 0.9726 & 0.0057 & & \textbf{0.9748} & 0.0083 \\
# ability & medium & & \textbf{0.9400} & 0.0234 & & 0.9212 & 0.0404 \\
# ability & high & & 0.6308 & 0.4109 & & \textbf{0.8918} & 0.0173 \\
# item & source & & \textbf{0.9898} & 0.0027 & & 0.9856 & 0.0045 \\
# item & low & & 0.9570 & 0.0123 & & \textbf{0.9654} & 0.0048 \\
# item & medium & & \textbf{0.9328} & 0.0070 & & 0.9260 & 0.0091 \\
# item & high & & 0.7006 & 0.2733 & & \textbf{0.8414} & 0.0302 \\
# move & source & & 0.3960 & 0.3376 & & \textbf{0.9932} & 0.0058 \\
# move & low & & \textbf{0.9974} & 0.0040 & & 0.9928 & 0.0120 \\
# move & medium & & 0.9872 & 0.0059 & & \textbf{0.9892} & 0.0045 \\
# move & high & & \textbf{0.9894} & 0.0057 & & 0.9810 & 0.0161 \\
# pokemon & source & & \textbf{0.9830} & nan & & 0.9708 & 0.0113 \\
# pokemon & low & & \textbf{0.9592} & 0.0074 & & 0.9586 & 0.0127 \\
# pokemon & medium & & 0.8026 & 0.2795 & & \textbf{0.9336} & 0.0143 \\
# pokemon & high & & 0.6270 & 0.2508 & & \textbf{0.9102} & 0.0768 \\
# species & source & & 0.9994 & 0.0013 & & \textbf{0.9996} & 0.0005 \\
# species & low & & \textbf{0.9954} & 0.0033 & & 0.9944 & 0.0047 \\
# species & medium & & \textbf{0.9912} & 0.0062 & & 0.9884 & 0.0072 \\
# species & high & & 0.9550 & 0.0565 & & \textbf{0.9910} & 0.0027 \\
# \bottomrule
# \end{tabular}
# \end{table}
#     dataset   entity metric_type  mean_f1    std_f1  num_seeds  train_size  \
# 0   pokemon  ability    baseline   0.6308  0.410869          5         1.0
# 8   pokemon     item    baseline   0.7006  0.273260          5         1.0
# 19  pokemon     move    baseline   0.3960  0.337646          5         1.0
# 24  pokemon  pokemon    baseline   0.6270  0.250785          5         1.0
# 26  pokemon  pokemon    baseline   0.8026  0.279468          5         1.0
# 28  pokemon  pokemon        test   0.9102  0.076810          5         1.0
# 32  pokemon  species    baseline   0.9550  0.056467          5         1.0
#
#    pollution  epochs
# 0       high      10
# 8       high      10
# 19    source      10
# 24      high      10
# 26    medium      10
# 28      high      10
# 32      high      10
#        run_id   entity  seed  f1_score  precision  recall  iteration
# 0  9807012_12  pokemon     3     0.303      0.182   0.907          0
# 1  9807012_14  pokemon     5     0.921      0.907   0.935          0
# 2  9807012_10  pokemon     1     0.922      0.886   0.961          0
# 3  9807012_11  pokemon     2     0.922      0.886   0.961          0
# 4  9807012_13  pokemon     4     0.945      0.936   0.954          0
# \begin{table}[h]
# \centering
# \caption{Baseline (Ditto pure) vs. Phase 1 (Empty Relational Scores) vs. Phase 2 (Relational Scores based on Ground-Truth) - Dataset pokemon}
# \label{tab:prelim_exp_}
# \begin{tabular}{ll c cc c cc c cc}
# \toprule
#  & & & \multicolumn{2}{c}{\textbf{Baseline}} & & \multicolumn{2}{c}{\textbf{Phase 1}} & & \multicolumn{2}{c}{\textbf{Phase 2}} \\
# \cmidrule{4-5} \cmidrule{7-8} \cmidrule{10-11}
# \textbf{Entity} & \textbf{Pollution} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} & & \textbf{Mean} & \textbf{SD} \\
# \midrule
# ability & source & & 0.9838 & 0.0018 & & 0.9784 & 0.0153 & & \textbf{0.9924} & 0.0057 \\
# ability & low & & 0.9726 & 0.0057 & & 0.7956 & 0.3540 & & \textbf{0.9738} & 0.0088 \\
# ability & medium & & 0.9400 & 0.0234 & & 0.7868 & 0.3445 & & \textbf{0.9436} & 0.0247 \\
# ability & high & & 0.6308 & 0.4109 & & 0.8148 & 0.1570 & & \textbf{0.9126} & 0.0468 \\
# item & source & & \textbf{0.9898} & 0.0027 & & 0.9556 & 0.0747 & & 0.9884 & 0.0029 \\
# item & low & & 0.9570 & 0.0123 & & 0.9646 & 0.0084 & & \textbf{0.9668} & 0.0018 \\
# item & medium & & 0.9328 & 0.0070 & & 0.9252 & 0.0312 & & \textbf{0.9410} & 0.0052 \\
# item & high & & 0.7006 & 0.2733 & & 0.8284 & 0.1091 & & \textbf{0.8686} & 0.0259 \\
# move & source & & 0.3960 & 0.3376 & & 0.9964 & 0.0018 & & \textbf{0.9970} & 0.0030 \\
# move & low & & \textbf{0.9974} & 0.0040 & & 0.9956 & 0.0038 & & 0.9954 & 0.0047 \\
# move & medium & & 0.9872 & 0.0059 & & 0.9910 & 0.0027 & & \textbf{0.9946} & 0.0039 \\
# move & high & & \textbf{0.9894} & 0.0057 & & 0.9836 & 0.0137 & & 0.9874 & 0.0032 \\
# pokemon & source & & 0.9830 & nan & & 0.9434 & 0.0889 & & \textbf{0.9832} & 0.0046 \\
# pokemon & low & & 0.9592 & 0.0074 & & 0.8504 & 0.2558 & & \textbf{0.9636} & 0.0060 \\
# pokemon & medium & & 0.8026 & 0.2795 & & 0.9282 & 0.0212 & & \textbf{0.9434} & 0.0208 \\
# pokemon & high & & 0.6270 & 0.2508 & & 0.5784 & 0.3185 & & \textbf{0.9392} & 0.0395 \\
# species & source & & 0.9994 & 0.0013 & & \textbf{0.9996} & 0.0005 & & 0.9990 & 0.0017 \\
# species & low & & 0.9954 & 0.0033 & & 0.9942 & 0.0037 & & \textbf{0.9968} & 0.0028 \\
# species & medium & & \textbf{0.9912} & 0.0062 & & 0.9846 & 0.0157 & & 0.9902 & 0.0084 \\
# species & high & & 0.9550 & 0.0565 & & 0.9090 & 0.1689 & & \textbf{0.9926} & 0.0025 \\
# \bottomrule
# \end{tabular}
# \end{table}
